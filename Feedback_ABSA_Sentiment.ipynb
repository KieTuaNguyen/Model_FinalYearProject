# %% [markdown]
# # Feedback Aspect-Based Sentiment Analysis Pipeline
#
# This notebook combines preprocessing, aspect extraction, and sentiment analysis for Vietnamese customer feedback data.

# %% [markdown]
# ## 1. Setup and Imports

# %%
import pandas as pd
import numpy as np
import nltk
from nltk.tokenize import sent_tokenize
import warnings
import re
import emoji
import json
import torch
import time
import openai
from collections import Counter
from transformers import RobertaForSequenceClassification, AutoTokenizer
from tqdm.notebook import tqdm

warnings.filterwarnings('ignore')
nltk.download('punkt', quiet=True)

# Configure OpenAI settings for local LM Studio
openai.api_base = 'http://localhost:1234/v1'
openai.api_key = ''

# Load PhoBERT model for sentiment analysis
model = RobertaForSequenceClassification.from_pretrained("wonrax/phobert-base-vietnamese-sentiment")
tokenizer = AutoTokenizer.from_pretrained("wonrax/phobert-base-vietnamese-sentiment", use_fast=False)

# %% [markdown]
# ## 2. Text Preprocessing Functions

# %%
def remove_urls(text):
    """Remove URLs from text.
    
    Args:
        text (str): Input text containing URLs
        
    Returns:
        str: Text with URLs removed
    """
    url_pattern = re.compile(r'https?://\S+|www\.\S+')
    return url_pattern.sub(r'', text)

def remove_html_tags(text):
    """Remove HTML tags from text.
    
    Args:
        text (str): Input text containing HTML tags
        
    Returns:
        str: Clean text without HTML tags
    """
    html_pattern = re.compile('<.*?>')
    return html_pattern.sub(r'', text)

def remove_special_characters(text):
    """Remove special characters while preserving Vietnamese diacritics.
    
    Args:
        text (str): Input text with special characters
        
    Returns:
        str: Text with only alphanumeric and Vietnamese characters
    """
    pattern = re.compile(r'[^a-zA-Z0-9\s\u00C0-\u1EF9.,!?]')
    return pattern.sub(r'', text)

def remove_extra_spaces(text):
    """Remove redundant whitespace.
    
    Args:
        text (str): Input text with extra spaces
        
    Returns:
        str: Text with normalized spacing
    """
    return re.sub(r'\s+', ' ', text).strip()

def remove_hashtags(text):
    """Remove hashtags from text.
    
    Args:
        text (str): Input text containing hashtags
        
    Returns:
        str: Text with hashtags removed
    """
    return re.sub(r'#\w+', '', text)

def remove_phone_numbers(text):
    """Replace phone numbers with [PHONE] token.
    
    Args:
        text (str): Input text containing phone numbers
        
    Returns:
        str: Text with phone numbers masked
    """
    return re.sub(r'\b(?:\+?84|0)(?:\d{9,10})\b', '[PHONE]', text)

def is_meaningful(text, min_length=2, max_length=200, max_repetition_ratio=0.5, max_consonant_streak=5):
    """Check if text is meaningful based on various criteria.
    
    Args:
        text (str): Input text to evaluate
        min_length (int): Minimum character length
        max_length (int): Maximum character length 
        max_repetition_ratio (float): Maximum ratio of most common character
        max_consonant_streak (int): Maximum consecutive consonants allowed
        
    Returns:
        bool: True if text is meaningful, False otherwise
    """
    cleaned_text = re.sub(r'[^\w\s]', '', text.lower())
    
    if len(cleaned_text) < min_length or len(cleaned_text) > max_length:
        return False
    
    if re.search(r'[bcdfghjklmnpqrstvwxyz]{' + str(max_consonant_streak) + ',}', cleaned_text):
        return False
    
    char_counts = Counter(cleaned_text)
    most_common_char_count = char_counts.most_common(1)[0][1]
    repetition_ratio = most_common_char_count / len(cleaned_text)
    
    if repetition_ratio > max_repetition_ratio:
        return False
    
    for pattern_length in range(2, 6):
        for i in range(len(cleaned_text) - pattern_length * 2):
            pattern = cleaned_text[i:i+pattern_length]
            if pattern == cleaned_text[i+pattern_length:i+pattern_length*2]:
                return False
    
    return True

def clean_text(text):
    """Apply all cleaning operations to text.
    
    Args:
        text (str): Raw input text
        
    Returns:
        str: Fully cleaned text
    """
    text = remove_urls(text)
    text = remove_html_tags(text)
    text = remove_hashtags(text)
    text = remove_phone_numbers(text)
    text = remove_special_characters(text)
    text = remove_extra_spaces(text)
    text = text.lower()
    text = emoji.demojize(text)
    return text

# %% [markdown]
# ## 3. LM Studio API Integration Functions

# %%
def get_completion(prompt, max_retries=3):
    """Get completion from local LM Studio API.
    
    Args:
        prompt (str): Input prompt for the model
        max_retries (int): Number of retries on failure
        
    Returns:
        str: Model completion response or None on failure
    """
    for attempt in range(max_retries):
        try:
            response = openai.ChatCompletion.create(
                model="local model",
                messages=[{"role": "user", "content": prompt}],
                temperature=0.1
            )
            return response.choices[0].message["content"]
        except Exception as e:
            print(f"Attempt {attempt + 1} failed: {str(e)}")
            if attempt < max_retries - 1:
                time.sleep(2)
    return None

def clean_and_validate_response(response):
    """Clean and validate JSON response from LM Studio.
    
    Args:
        response (str): Raw response from model
        
    Returns:
        dict: Parsed JSON response or None if invalid
    """
    if not response:
        return None
    try:
        return json.loads(response)
    except json.JSONDecodeError:
        try:
            json_start = response.find('{')
            json_end = response.rfind('}') + 1
            if json_start >= 0 and json_end > json_start:
                return json.loads(response[json_start:json_end])
        except:
            pass
    return None

# %% [markdown]
# ## 4. Sentiment Analysis Functions

# %%
def analyze_sentiment(text):
    """Analyze sentiment of text using PhoBERT model.
    
    Args:
        text (str): Input text for sentiment analysis
        
    Returns:
        dict: Sentiment probabilities for negative, positive, neutral
    """
    input_ids = torch.tensor([tokenizer.encode(text)])
    with torch.no_grad():
        out = model(input_ids)
        probs = out.logits.softmax(dim=-1).tolist()[0]
    return {
        "Negative": probs[0],
        "Positive": probs[1],
        "Neutral": probs[2]
    }

def get_dominant_sentiment(sentiment_dict):
    """Get the dominant sentiment from probability distribution.
    
    Args:
        sentiment_dict (dict): Sentiment probabilities
        
    Returns:
        str: Dominant sentiment category
    """
    return max(sentiment_dict, key=sentiment_dict.get)

def sentiment_to_polarity(sentiment):
    """Convert sentiment category to polarity label.
    
    Args:
        sentiment (str): Sentiment category
        
    Returns:
        str: Polarity label (NEG, POS, NEU)
    """
    mapping = {
        "negative": "NEG",
        "positive": "POS",
        "neutral": "NEU"
    }
    return mapping.get(sentiment.lower(), "NEU")

# %% [markdown]
# ## 5. Main Processing Functions

# %%
def process_feedback(feedback):
    """Process feedback by extracting and analyzing aspects.
    
    Args:
        feedback (dict): Feedback entry with content and aspects
        
    Returns:
        list: Processed aspects with sentiment analysis
    """
    content = feedback['Content']
    results = []
    
    for aspect in feedback['Aspects']:
        if len(aspect['AspectTerms']) == 0:
            results.append({
                'AspectCategory': aspect['AspectCategory'],
                'AspectTerms': [],
                'Polarity': None,
                'DominantScore': None
            })
        else:
            for term in aspect['AspectTerms']:
                start = max(0, content.find(term) - 20)
                end = min(len(content), content.find(term) + len(term) + 20)
                context = content[start:end]
                
                sentiment = analyze_sentiment(context)
                dominant_sentiment = get_dominant_sentiment(sentiment)
                dominant_score = round(sentiment[dominant_sentiment], 3)
                
                results.append({
                    'AspectCategory': aspect['AspectCategory'],
                    'AspectTerms': term,
                    'Polarity': sentiment_to_polarity(dominant_sentiment),
                    'DominantScore': dominant_score
                })
    
    return results

def process_single_feedback(feedback):
    """Process single feedback entry through LM Studio.
    
    Args:
        feedback (dict): Feedback entry
        
    Returns:
        dict: Processed feedback with aspects or None
    """
    prompt = f'''### Instruction:
Analyze this feedback and extract aspects. Return ONLY a JSON object:
{json.dumps(feedback, ensure_ascii=False)}

Required format:
{{
    "GeneralFeedbackID": {feedback["GeneralFeedbackID"]},
    "ID": {feedback["ID"]},
    "Content": "{feedback["Content"]}",
    "Aspects": [
        {{
            "AspectCategory": "Về Sản Phẩm",
            "AspectTerms": []
        }},
        {{
            "AspectCategory": "Về Dịch Vụ", 
            "AspectTerms": []
        }}
    ]
}}
### Response:'''
    
    response = get_completion(prompt)
    if response:
        return clean_and_validate_response(response)
    return None

# %% [markdown]
# ## 6. Main Pipeline Execution

# %%
# Load and preprocess data
print("\n=== Loading and Preprocessing Data ===")
df = pd.read_csv('warehouse/feedback/CustomerSatisfaction.csv', encoding='utf-8-sig')
initial_count = len(df)
print(f'[INFO] Loaded {initial_count:,} initial records')

# Basic preprocessing
df = df[['GeneralFeedbackID', 'Content']].drop_duplicates(subset='GeneralFeedbackID', keep='first')
dedup_count = len(df)
print(f'[INFO] After deduplication: {dedup_count:,} records ({initial_count - dedup_count:,} duplicates removed)')

df['Content'] = df['Content'].astype(str)
print('[INFO] Converted content to string type')

# Clean and tokenize
print("\n=== Cleaning and Filtering ===")
print('[INFO] Applying text cleaning...')
df['Content'] = df['Content'].apply(clean_text)
df['is_meaningful'] = df['Content'].apply(is_meaningful)
df = df[df['is_meaningful']]
df = df.drop(columns=['is_meaningful'])
df = df[df['Content'].str.strip().astype(bool)]
final_count = len(df)
print(f'[INFO] After cleaning: {final_count:,} meaningful records')
print(f'[INFO] Removed {dedup_count - final_count:,} non-meaningful entries')

# Process through LM Studio
print("\n=== Processing through LM Studio ===")
processed_results = []
success_count = 0
failed_count = 0
for idx, row in tqdm(df.iterrows(), total=len(df), desc="Processing feedback"):
    feedback = {
        'GeneralFeedbackID': row['GeneralFeedbackID'],
        'ID': idx,
        'Content': row['Content']
    }
    processed = process_single_feedback(feedback)
    if processed:
        processed_results.append(processed)
        success_count += 1
    else:
        failed_count += 1

print(f'[INFO] Successfully processed {success_count:,} entries')
print(f'[INFO] Failed to process {failed_count:,} entries')
# Out:
# === Loading and Preprocessing Data ===
# [INFO] Loaded 5,015 initial records
# [INFO] After deduplication: 2,858 records (2,157 duplicates removed)
# [INFO] Converted content to string type
#
# === Cleaning and Filtering ===
# [INFO] Applying text cleaning...
# [INFO] After cleaning: 2,503 meaningful records
# [INFO] Removed 355 non-meaningful entries
#
# === Processing through LM Studio ===
# Processing feedback:   0%|          | 0/2503 [00:00<?, ?it/s]
# [INFO] Successfully processed 2,502 entries
# [INFO] Failed to process 1 entries
#
# === Performing Sentiment Analysis ===
# Analyzing sentiment:   0%|          | 0/2502 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[24], line 56
#      50 final_results = []
#      51 for feedback in tqdm(processed_results, desc="Analyzing sentiment"):
#      52     processed_feedback = {
#      53         'GeneralFeedbackID': feedback['GeneralFeedbackID'],
#      54         'ID': feedback['ID'],
#      55         'Content': feedback['Content'],
# ---> 56         'Aspects': process_feedback(feedback)
#      57     }
#      58     final_results.append(processed_feedback)
#      60 print(f'[INFO] Completed sentiment analysis for {len(final_results):,} entries')
#
# Cell In[23], line 14, in process_feedback(feedback)
#      11 results = []
#      13 for aspect in feedback['Aspects']:
# ---> 14     if len(aspect['AspectTerms']) == 0:
#      15         results.append({
#      16             'AspectCategory': aspect['AspectCategory'],
#      17             'AspectTerms': [],
#      18             'Polarity': None,
#      19             'DominantScore': None
#      20         })
#      21     else:
#
# KeyError: 'AspectTerms'

# %%
processed_results
# Out:
# [{'GeneralFeedbackID': 14766294,
#   'ID': 0,
#   'Content': 'hàng nguyên seal, chất lượng ổn hơn các dòng android tablet khác. dùng để lướt web, xem phim tốt.',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm',
#     'AspectTerms': ['nguyên seal', 'chất lượng ổn']},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 19380399,
#   'ID': 1,
#   'Content': 'giá tốt, hàng xịn, tiki luôn là lựa chọn số 1 của tôi!',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm',
#     'AspectTerms': ['giá tốt', 'hàng xịn']},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 15188338,
#   'ID': 2,
#   'Content': 'máy chính hãng nguyên seal, kiểm tra mã imei thì chưa kích hoạt, giá tốt. hàng được xử lí nhanh, đóng gói kỹ lưỡng chắc chắn. giao đúng hẹn.',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm',
#     'AspectTerms': ['chính hãng', 'nguyên seal', 'giá tốt']},
#    {'AspectCategory': 'Về Dịch Vụ',
#     'AspectTerms': ['xử lí nhanh', 'đóng gói kỹ lưỡng', 'giao đúng hẹn']}]},
#  {'GeneralFeedbackID': 19342921,
#   'ID': 3,
#   'Content': 'đúng chuẩn apple. ipad mới tinh, hàng của tiki trading phân phối nên chất lượng cực kỳ ổn, yên tâm.',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm',
#     'AspectTerms': ['chất lượng', 'ổn']},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 18078725,
#   'ID': 4,
#   'Content': 'máy tốt, tiki giao hàng nhanh',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm', 'AspectTerms': ['tốt']},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': ['giao hàng nhanh']}]},
#  {'GeneralFeedbackID': 15463515,
#   'ID': 6,
#   'Content': 'sản phẩm tốt, giao nhanh',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm', 'AspectTerms': ['tốt']},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': ['giao nhanh']}]},
#  {'GeneralFeedbackID': 16190785,
#   'ID': 7,
#   'Content': 'giao hàng nhanh',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm', 'AspectTerms': []},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 18794025,
#   'ID': 8,
#   'Content': 'vừa mua xong thì giảm còn 6tr9! buồn',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm', 'AspectTerms': ['giảm giá']},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 18798907,
#   'ID': 9,
#   'Content': 'ok! khớp với mô tả. mua cho người lớn xem giải trí youtube và tin tức rất phù hợp',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm',
#     'AspectTerms': ['khớp với mô tả']},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 19919896,
#   'ID': 10,
#   'Content': 'sản phẩm mới, chất lượng cao, và không có tính năng gì mới mẻ.',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm',
#     'AspectTerms': ['mới', 'chất lượng cao']},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 15795137,
#   'ID': 11,
#   'Content': 'chính hãng',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm', 'AspectTerms': []},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 15363555,
#   'ID': 12,
#   'Content': 'ok',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm', 'AspectTerms': []},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 18280279,
#   'ID': 13,
#   'Content': 'sp dùng ổn, hàng chính hãng, sẽ tiếp tục mua hàng',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm',
#     'AspectTerms': ['dùng ổn', 'hàng chính hãng']},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 15209089,
#   'ID': 14,
#   'Content': 'tiki giao hàng nhanh, đóng gói cẩn thận, hàng chính hãng.',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm',
#     'AspectTerms': ['hàng chính hãng']},
#    {'AspectCategory': 'Về Dịch Vụ',
#     'AspectTerms': ['giao hàng nhanh', 'đóng gói cẩn thận']}]},
#  {'GeneralFeedbackID': 18982859,
#   'ID': 15,
#   'Content': 'dùng ổn lắm nha mng, mình dùng cho việc học và edit video ngắn nên phù hợp với nhu cầu sử dụng.',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm', 'AspectTerms': ['dùng ổn']},
#    {'AspectCategory': 'Về Dịch Vụ',
#     'AspectTerms': ['phù hợp với nhu cầu sử dụng']}]},
#  {'GeneralFeedbackID': 14919249,
#   'ID': 16,
#   'Content': 'hàng đẹp, nguyên seal, đóng gói chắc chắn, giao trong chớp mắt.',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm',
#     'AspectTerms': ['đẹp', 'nguyên seal', 'chắc chắn']},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': ['giao trong chớp mắt']}]},
#  {'GeneralFeedbackID': 15470861,
#   'ID': 18,
#   'Content': 'hàng chính hãng, giao hàng nhanh, chất lượng tốt',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm',
#     'AspectTerms': ['chính hãng', 'nhanh', 'tốt']},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': ['giao hàng nhanh']}]},
#  {'GeneralFeedbackID': 15539385,
#   'ID': 19,
#   'Content': 'giao hàng nhanh chóng mặt',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm',
#     'AspectTerms': ['nhanh', 'mặt']},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': ['giao hàng']}]},
#  {'GeneralFeedbackID': 19073753,
#   'ID': 20,
#   'Content': 'mình hài lòng về hiệu năng của chiếc ipad này',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm', 'AspectTerms': ['hiệu năng']},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 19769438,
#   'ID': 21,
#   'Content': 'nhiều lần mua đồ điện tử trên tiki, lần nào cũng làm mình hài lòng, giao đúng hẹn, hàng nguyên seal, rất tốt',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm',
#     'AspectTerms': ['hàng nguyên seal']},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': ['giao đúng hẹn']}]},
#  {'GeneralFeedbackID': 15690305,
#   'ID': 22,
#   'Content': 'máy rat đẹp, ngoài ra mình tải thêm tbooks tải ebook miễn phí , camera cũng rất tốt',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm', 'AspectTerms': ['đẹp']},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': ['miễn phí']}]},
#  {'GeneralFeedbackID': 19217622,
#   'ID': 23,
#   'Content': 'ok, thích hợp cho bé học tập',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm', 'AspectTerms': []},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 18613091,
#   'ID': 24,
#   'Content': 'tiki luôn ok. tai phone mình mua thêm nhé!',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm', 'AspectTerms': ['tốt', 'đẹp']},
#    {'AspectCategory': 'Về Dịch Vụ',
#     'AspectTerms': ['hỗ trợ khách hàng tốt']}]},
#  {'GeneralFeedbackID': 14879590,
#   'ID': 25,
#   'Content': 'giao hàng nhanh, gói hàng kỹ. sản phẩm đúng như mong đợi. mua từ tiki giá tốt hơn các nhà bán lẻ khác rất nhiều.',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm',
#     'AspectTerms': ['đúng như mong đợi']},
#    {'AspectCategory': 'Về Dịch Vụ',
#     'AspectTerms': ['giao hàng nhanh', 'gói hàng kỹ']}]},
#  {'GeneralFeedbackID': 18754453,
#   'ID': 26,
#   'Content': 'hàng đảm bảo chắc chắn mã zaa',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm',
#     'AspectTerms': ['đảm', 'chắc', 'sản phẩm']},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 15780870,
#   'ID': 27,
#   'Content': 'hàng nguyên seal, đóng gói cẩn thận, giao nhanh.',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm',
#     'AspectTerms': ['nguyên seal', 'đóng gói cẩn thận']},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': ['giao nhanh']}]},
#  {'GeneralFeedbackID': 19619448,
#   'ID': 28,
#   'Content': 'rất tốt.',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm', 'AspectTerms': []},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 19192977,
#   'ID': 30,
#   'Content': 'giao hàng nhanh. sản phẩm nguyên hộp. lần 2 mua ipad từ tiki trading',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm',
#     'AspectTerms': ['giao hàng nhanh', 'sản phẩm nguyên hộp']},
#    {'AspectCategory': 'Về Dịch Vụ',
#     'AspectTerms': ['giao hàng nhanh', 'mua lần 2 từ tiki trading']}]},
#  {'GeneralFeedbackID': 18740113,
#   'ID': 31,
#   'Content': 'rất tốt trong tầm giá.',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm', 'AspectTerms': []},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 19527943,
#   'ID': 32,
#   'Content': 'mới ba tháng sụp nguồn hỏng pin.',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm', 'AspectTerms': []},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 19142516,
#   'ID': 33,
#   'Content': 'hàng ngon,chất lượng, chính hãng',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm',
#     'AspectTerms': ['ngon', 'chất lượng', 'chính hãng']},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 15917490,
#   'ID': 34,
#   'Content': 'ok',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm', 'AspectTerms': []},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 15063230,
#   'ID': 35,
#   'Content': 'giao hàng nhanh, hàng nguyên siêu, đầy đủ đúng mẫu',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm',
#     'AspectTerms': ['hàng nguyên', 'đầy đủ', 'đúng mẫu']},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': ['giao hàng nhanh']}]},
#  {'GeneralFeedbackID': 18647345,
#   'ID': 36,
#   'Content': 'ngon bổ rẻ ship siêu nhanh. mỗi tội đặt màu trắng lại giao đen nhưng thôi ko sao đen càng đẹp',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm',
#     'AspectTerms': ['ngon', 'bổ', 'rẻ', 'ship', 'siêu nhanh']},
#    {'AspectCategory': 'Về Dịch Vụ',
#     'AspectTerms': ['đặt màu trắng', 'giao đen']}]},
#  {'GeneralFeedbackID': 16679070,
#   'ID': 37,
#   'Content': 'ok',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm', 'AspectTerms': []},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 15327512,
#   'ID': 38,
#   'Content': 'ipad nhẹ, đẹp, nhạy và mua được gía rẩt tốt khi sử dụng thêm khuyến mãi thẻ. giao hàng siêu nhanh. sẽ tiếp tục ủng hộ tiki',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm',
#     'AspectTerms': ['nhẹ', 'đẹp', 'nhạy']},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': ['giao hàng siêu nhanh']}]},
#  {'GeneralFeedbackID': 15300367,
#   'ID': 39,
#   'Content': 'hàng quá ngon, dùng cực kỳ ưng ý. đợi giảm giá làm thêm 1 con nữa. mua giá quá rẻ.',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm', 'AspectTerms': ['quá ngon']},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 15173242,
#   'ID': 40,
#   'Content': 'hàng tiki trading thì ko phải nghĩ. giá cũng hợp lý. mua học online thì quất thôi.',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm', 'AspectTerms': ['giá hợp lý']},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 19809175,
#   'ID': 41,
#   'Content': 'rất ok',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm', 'AspectTerms': []},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 14982698,
#   'ID': 42,
#   'Content': 'ok',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm', 'AspectTerms': []},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 15148578,
#   'ID': 43,
#   'Content': 'giao hàng nhanh hơn dự kiến 2 ngày. đóng gói cẩn thận! cảm ơn tiki!',
#   'Aspects': [{'AspectCategory': 'Về Dịch Vụ',
#     'AspectTerms': ['giao hàng nhanh hơn dự kiến 2 ngày',
#      'đóng gói cẩn thận']}]},
#  {'GeneralFeedbackID': 19831603,
#   'ID': 44,
#   'Content': 'mọi thứ đều ổn.',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm', 'AspectTerms': []},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 14766029,
#   'ID': 45,
#   'Content': 'ok thôi.',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm', 'AspectTerms': []},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 19581536,
#   'ID': 46,
#   'Content': 'máy đẹp',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm', 'AspectTerms': []},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 19846888,
#   'ID': 47,
#   'Content': '10 điểm, máy dùng tốt. mua về học tập làm việc thao tác cơ bản thì máy này quá tốt.',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm', 'AspectTerms': ['dùng tốt']},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 15330672,
#   'ID': 48,
#   'Content': 'đúng hàng chính hãng!',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm', 'AspectTerms': []},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 15100200,
#   'ID': 49,
#   'Content': 'giao nhanh',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm', 'AspectTerms': []},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 18189549,
#   'ID': 50,
#   'Content': 'hàng chuẩn, giao nhanh, mình mua được giá 7tr1 cũng rẻ rồi. cáp sạc xịn pass lại cũng đỡ được vài trăm.',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm',
#     'AspectTerms': ['hàng chuẩn', 'giá 7tr1']},
#    {'AspectCategory': 'Về Dịch Vụ',
#     'AspectTerms': ['giao nhanh', 'pass lại cũng đỡ được vài trăm']}]},
#  {'GeneralFeedbackID': 18152948,
#   'ID': 51,
#   'Content': 'máy xịn, nguyên bản, dùng rất mượt mà giá lại đang rẻ',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm',
#     'AspectTerms': ['xịn', 'nguyên bản', 'dùng rất mượt']},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 15672596,
#   'ID': 52,
#   'Content': 'rẻ',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm', 'AspectTerms': []},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 18707444,
#   'ID': 53,
#   'Content': 'hàng chất lượng tốt, giao nhanh. vẫn còn nguyên seal',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm',
#     'AspectTerms': ['chất lượng tốt']},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': ['giao nhanh']}]},
#  {'GeneralFeedbackID': 17741175,
#   'ID': 54,
#   'Content': 'máy tốt, giao hành nhanh. mình dùng thấy mượt mà ko vấn đề gì highly recommend nha!',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm',
#     'AspectTerms': ['tốt', 'mượt']},
#    {'AspectCategory': 'Về Dịch Vụ',
#     'AspectTerms': ['giao hành nhanh', 'highly recommend']}]},
#  {'GeneralFeedbackID': 19092281,
#   'ID': 55,
#   'Content': 'ngon nghẻ trong tầm giá ko có gì để chê',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm',
#     'AspectTerms': ['ngon', 'nghẻ']},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 18196234,
#   'ID': 56,
#   'Content': 'săn sale với ưu đãi thanh toán.còn 7t3 quá ngon trong tầm giá , nhận hành nhanh chóng, ipad xài tốt ko vde gì , nên mua nha mn',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm',
#     'AspectTerms': ['ngon', 'tầm giá']},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': ['nhanh chóng']}]},
#  {'GeneralFeedbackID': 18843127,
#   'ID': 57,
#   'Content': 'chưa xài cho trước rồi tính sau',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm', 'AspectTerms': []},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 17777331,
#   'ID': 58,
#   'Content': 'good!',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm', 'AspectTerms': []},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 14734902,
#   'ID': 59,
#   'Content': 'rất thíc tiki giao hàng siêu nhanh',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm',
#     'AspectTerms': ['tích', 'siêu']},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': ['giao']}]},
#  {'GeneralFeedbackID': 14826863,
#   'ID': 61,
#   'Content': 'tikinow giao hàng siêu nhanh, đóng gói hộp rất cẩn thận. hàng chính hãng của apple vn, mã za nha mọi người. yên tâm là có bảo hành chính hãng tại vn. máy nguyên seal đầy đủ phụ kiện nên ko lo',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm',
#     'AspectTerms': ['hàng chính hãng', 'máy nguyên seal']},
#    {'AspectCategory': 'Về Dịch Vụ',
#     'AspectTerms': ['giao hàng siêu nhanh',
#      'đóng gói hộp rất cẩn thận',
#      'bảo hành chính hãng tại vn']}]},
#  {'GeneralFeedbackID': 19331019,
#   'ID': 62,
#   'Content': 'giao hàng cực nhanh',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm', 'AspectTerms': []},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 16910870,
#   'ID': 63,
#   'Content': 'hàng chính hãng apple, khi giao còn nguyên seal, full box',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm',
#     'AspectTerms': ['chính hãng', 'apple', 'nguyên seal']},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 15148944,
#   'ID': 64,
#   'Content': 'giao hành nhanh. đóng gói cẩn thận. hàng mới 2022',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm',
#     'AspectTerms': ['giao hành nhanh', 'hàng mới 2022']},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': ['đóng gói cẩn thận']}]},
#  {'GeneralFeedbackID': 16532686,
#   'ID': 65,
#   'Content': 'giao nhanh, hàng chính hãng',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm',
#     'AspectTerms': ['giao nhanh', 'hàng chính hãng']},
#    {'AspectCategory': 'Về Dịch Vụ'}]},
#  {'GeneralFeedbackID': 18631820,
#   'ID': 66,
#   'Content': 'mua với giá sale off còn 7 tr, xem video quá ổn trong tầm giá, ipad nổi tiếng trâu bò',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm',
#     'AspectTerms': ['giá', 'tầm giá']},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 17222496,
#   'ID': 67,
#   'Content': 'giao hàng nhanh chất lượng sản phẩm tốt',
#   'Aspects': [{'AspectCategory': 'Về Dịch Vụ',
#     'AspectTerms': ['giao hàng nhanh']},
#    {'AspectCategory': 'Về Sản Phẩm',
#     'AspectTerms': ['chất lượng sản phẩm tốt']}]},
#  {'GeneralFeedbackID': 15496271,
#   'ID': 68,
#   'Content': 'giao nhanh lắm luôn ý',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm', 'AspectTerms': []},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 18930108,
#   'ID': 69,
#   'Content': 'goog',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm', 'AspectTerms': []},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 18142636,
#   'ID': 70,
#   'Content': 'mua xong mới phát hiện có nút homenicator vẫn chưa phải nhận dạng khuôn mặt ko full màn hình so với gen 10 thì gen 10 ok hơn thanks shop , và anh vận chuyển ok lắm',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm',
#     'AspectTerms': ['nút homenicator',
#      'nhận dạng khuôn mặt',
#      'full màn hình']},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': ['vận chuyển']}]},
#  {'GeneralFeedbackID': 14667945,
#   'ID': 71,
#   'Content': 'sản phẩm rất tốt.tiki giao bị chậm trễ 2 ngày.',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm', 'AspectTerms': ['tốt']},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': ['chậm trễ']}]},
#  {'GeneralFeedbackID': 14213145,
#   'ID': 72,
#   'Content': 'giao nhanh hơn dự kiến. hàng nguyên dai nguyên kiện.',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm',
#     'AspectTerms': ['giao nhanh', 'hàng nguyên']},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': ['dự kiến']}]},
#  {'GeneralFeedbackID': 19118517,
#   'ID': 73,
#   'Content': 'hàng giao nhanh chóng, bảo hành apple đến tận tháng 4 năm sau. mua trên tiki công nhận sướng thật',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm',
#     'AspectTerms': ['hàng giao nhanh chóng', 'bảo hành apple']},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': ['mua trên tiki']}]},
#  {'GeneralFeedbackID': 18139513,
#   'ID': 74,
#   'Content': 'rất phù hợp với tôi. mới nguyên 100.',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm',
#     'AspectTerms': ['phù hợp', 'mới nguyên']},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 19109632,
#   'ID': 75,
#   'Content': 'giao nhanh, máy phù hợp cho phụ huynh giải trí',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm',
#     'AspectTerms': ['giao nhanh', 'phù hợp']},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 19468291,
#   'ID': 76,
#   'Content': 'giao hàng quá chậm, nhân viên xử lý thông tin nhắn tin cho qua chuyện, cũng chẳng giải quyết được gì',
#   'Aspects': [{'AspectCategory': 'Về Dịch Vụ',
#     'AspectTerms': ['giao hàng quá chậm',
#      'nhân viên xử lý thông tin nhắn tin cho qua chuyện']},
#    {'AspectCategory': 'Về Sản Phẩm', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 18199649,
#   'ID': 77,
#   'Content': 'hộp hơi móp góc, nhưng ko ảnh hưởng ji máy, tiki đóng gói kĩ, giá tốt so với các shop bên ngoài, hiện tại dùng chưa có vấn đề ji, hi vọng bền',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm',
#     'AspectTerms': ['hộp hơi móp góc', 'giá tốt']},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': ['tiki đóng gói kĩ']}]},
#  {'GeneralFeedbackID': 14816438,
#   'ID': 78,
#   'Content': 'giao hàng đúng thời gian, bọc cẩn thận. sản phẩm tốt, khá hài lòng.',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm',
#     'AspectTerms': ['giao hàng đúng thời gian', 'bọc cẩn thận']},
#    {'AspectCategory': 'Về Dịch Vụ',
#     'AspectTerms': ['giao hàng đúng thời gian', 'sản phẩm tốt']}]},
#  {'GeneralFeedbackID': 19440391,
#   'ID': 79,
#   'Content': 'lỗi bị cấn viền. mong tiki giải quyết',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm',
#     'AspectTerms': ['lỗi', 'cấn viền']},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': ['giải quyết']}]},
#  {'GeneralFeedbackID': 14801401,
#   'ID': 80,
#   'Content': 'máy ổn và đẹp. duy nhất 1 điểm máy minh bên dưới màn có một vết đen nhỏ k thể lấy đc nhưng mình cũng dể tính nên nó cũng ảnh hưởng mình mấy. như hình cái chấm đen',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm', 'AspectTerms': ['ổn', 'đẹp']},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 18918972,
#   'ID': 81,
#   'Content': 'giao hàng nhanh, đóng gói tốt, xuất hoá đơn điện tử đầy đủ, thấy mấy lần mua có tem niêm phong nhưng đợt này không có',
#   'Aspects': [{'AspectCategory': 'Về Dịch Vụ',
#     'AspectTerms': ['Giao hàng nhanh',
#      'Đóng gói tốt',
#      'Xuất hoá đơn điện tử đầy đủ']},
#    {'AspectCategory': 'Về Sản Phẩm', 'AspectTerms': ['Tem niêm phong']}]},
#  {'GeneralFeedbackID': 18920599,
#   'ID': 82,
#   'Content': 'nguyên seal. sản phẩm giao nguyên vẹn, đúng mẫu đã đặt.',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm',
#     'AspectTerms': ['nguyên seal',
#      'sản phẩm giao nguyên vẹn',
#      'đúng mẫu đã đặt']},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 18619253,
#   'ID': 83,
#   'Content': 'đánh giá không tính điểm tệ. gói hàng và vận chuyển hàng không cẩm thận. sản phẩm giá trị cao mà lúc nhận nát tè le',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm',
#     'AspectTerms': ['không tính điểm tệ', 'nát tè le']},
#    {'AspectCategory': 'Về Dịch Vụ',
#     'AspectTerms': ['gói hàng không cẩn thận',
#      'vận chuyển hàng không cẩn thận']}]},
#  {'GeneralFeedbackID': 18528247,
#   'ID': 84,
#   'Content': 'tiki ship nhanh. đóng gói cẩn thận. máy mới nguyên seal. sử dụng chưa thấy lỗi lầm gì. máy mượt, pin trâu.',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm',
#     'AspectTerms': ['máy mới', 'nguyên seal', 'sử dụng chưa thấy lỗi lầm gì']},
#    {'AspectCategory': 'Về Dịch Vụ',
#     'AspectTerms': ['tiki ship nhanh', 'đóng gói cẩn thận']}]},
#  {'GeneralFeedbackID': 15394542,
#   'ID': 85,
#   'Content': 'giao hàng nhanh. máy siêu đẹp',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm', 'AspectTerms': ['siêu đẹp']},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': ['giao hàng nhanh']}]},
#  {'GeneralFeedbackID': 14761492,
#   'ID': 86,
#   'Content': 'thích mua đồ công nghệ trên tiki vì giá tốt và có giao nhanh',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm', 'AspectTerms': ['giá tốt']},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': ['giao nhanh']}]},
#  {'GeneralFeedbackID': 14981631,
#   'ID': 87,
#   'Content': 'hàng đóng gói cẩn thận, nguyên đai nguyên kiện. tiki giao hàng siêu nhanh',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm',
#     'AspectTerms': ['đóng gói cẩn thận', 'nguyên đai nguyên kiện']},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': ['giao hàng siêu nhanh']}]},
#  {'GeneralFeedbackID': 15815866,
#   'ID': 88,
#   'Content': 'ok',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm', 'AspectTerms': []},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 19100707,
#   'ID': 89,
#   'Content': 'hàng chuẩn, nét, tốt trong tầm giá, giao nhanh!',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm', 'AspectTerms': ['chùn', 'ᭃt']},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 15728723,
#   'ID': 90,
#   'Content': 'hài lòng. sản phẩm giao nhanh, nguyên seal và dùng 1 thời gian rất ổn.',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm',
#     'AspectTerms': ['giao nhanh', 'nguyên seal']},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 18578840,
#   'ID': 91,
#   'Content': 'good',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm', 'AspectTerms': []},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 17826918,
#   'ID': 92,
#   'Content': 'đóng gói kỹ máy đẹp.',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm',
#     'AspectTerms': ['đóng', 'gói', 'kỹ', 'máy']},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 18094826,
#   'ID': 93,
#   'Content': 'mới nhận hàng, mọi thứ đều ổn từ giao hàng cho tới bóc hộp',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm',
#     'AspectTerms': ['hàng', 'bóc hộp']},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': ['giao hàng']}]},
#  {'GeneralFeedbackID': 19201195,
#   'ID': 94,
#   'Content': 'ok',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm', 'AspectTerms': []},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 14752860,
#   'ID': 95,
#   'Content': 'rõ ràng ghi thích ứng với apple pencil 2 bây giờ tui mua apple pencil 2 cùng lúc với ipad thì không kết nối được. tiki ghi mô tả sản phẩm kiểu gì vậy. giờ làm gì với cái pencil 2',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm',
#     'AspectTerms': ['khả năng tương thích', 'mua cùng lúc']},
#    {'AspectCategory': 'Về Dịch Vụ',
#     'AspectTerms': ['hỗ trợ khách hàng', 'giải quyết vấn đề']}]},
#  {'GeneralFeedbackID': 19522906,
#   'ID': 97,
#   'Content': 'good',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm', 'AspectTerms': []},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 14618423,
#   'ID': 99,
#   'Content': 'hàng chính hãng, giá tốt, giao siêu nhanh, chất lượng miễn bàn, có đủ sạc nhanh và cáp,mn cứ săn sale là tiết kiệm được 1 khoản tiền..',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm',
#     'AspectTerms': ['chính hãng',
#      'giá tốt',
#      'giao siêu nhanh',
#      'chất lượng miễn bàn']},
#    {'AspectCategory': 'Về Dịch Vụ',
#     'AspectTerms': ['sạc nhanh', 'cáp', 'sale']}]},
#  {'GeneralFeedbackID': 19705537,
#   'ID': 100,
#   'Content': 'giao hàng nhanh, đóng gói cẩn thận.',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm',
#     'AspectTerms': ['giao hàng nhanh', 'đóng gói cẩn thận']},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 20010659,
#   'ID': 101,
#   'Content': 'máy mới nguyên seal, chạy mượt. màn hình đẹp',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm',
#     'AspectTerms': ['mới', 'nguyên seal', 'chạy mượt']},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 19405497,
#   'ID': 102,
#   'Content': 'máy tốt xài ổn định chưa có trục trặc gì',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm',
#     'AspectTerms': ['tốt', 'xài ổn định']},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 15603857,
#   'ID': 103,
#   'Content': 'giao hàng nhanh, hôm sau có hàng luôn. đóng gói cẩn thận. máy dùng thích lắm',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm',
#     'AspectTerms': ['giao hàng nhanh', 'hôm sau có hàng luôn']},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': ['đóng gói cẩn thận']}]},
#  {'GeneralFeedbackID': 16305765,
#   'ID': 104,
#   'Content': 'giao hàng nhanh 2h là có. đóng gói rất chắc chắn và có mã otp cho hàng giá trị cao nên rất an tâm khi đặt. ipad mượt mà , chạy ổn. tương thích với apple pencil 1 luôn. rất hài lòng về dịch vụ của tiki.',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm',
#     'AspectTerms': ['giao hàng nhanh',
#      'đóng gói chắc chắn',
#      'mượt mà',
#      'chạy ổn']},
#    {'AspectCategory': 'Về Dịch Vụ',
#     'AspectTerms': ['giao hàng nhanh', 'có mã otp', 'an tâm khi đặt']}]},
#  {'GeneralFeedbackID': 15547918,
#   'ID': 105,
#   'Content': 'đóng gói cẩn thận. giao hàng rất nhanh. hài lòng với chất lượng và dịch vụ của tiki.',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm', 'AspectTerms': ['cẩn thận']},
#    {'AspectCategory': 'Về Dịch Vụ',
#     'AspectTerms': ['giao hàng nhanh', 'chất lượng', 'dịch vụ']}]},
#  {'GeneralFeedbackID': 15913417,
#   'ID': 106,
#   'Content': 'giao hành nhanh trong 2h, đóng gói cẩn thận, nhân viên giao hàng nhiệt tình.',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm',
#     'AspectTerms': ['giao hành nhanh', 'đóng gói cẩn thận']},
#    {'AspectCategory': 'Về Dịch Vụ',
#     'AspectTerms': ['nhân viên giao hàng nhiệt tình']}]},
#  {'GeneralFeedbackID': 13073310,
#   'ID': 107,
#   'Content': 'hàng chính hãng apple nguyên seal. giao hàng nhanh. hài lòng',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm',
#     'AspectTerms': ['chính hãng', 'apple', 'nguyên seal']},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': ['giao hàng nhanh']}]},
#  {'GeneralFeedbackID': 18216503,
#   'ID': 108,
#   'Content': 'hàng giao đẹp. chưa sài chưa biết ra sao',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm',
#     'AspectTerms': ['hàng giao đẹp']},
#    {'AspectCategory': 'Về Dịch Vụ',
#     'AspectTerms': ['chưa sài chưa biết ra sao']}]},
#  {'GeneralFeedbackID': 19631672,
#   'ID': 109,
#   'Content': 'hàng chính hãng, giá rẻ, máy đẹp',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm',
#     'AspectTerms': ['chính hãng', 'giá rẻ', 'máy đẹp']},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 19724962,
#   'ID': 110,
#   'Content': 'hàng nguyên hộp chưa kích hoạt.',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm', 'AspectTerms': []},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 19383159,
#   'ID': 111,
#   'Content': 'hàng đẹp nguyên seal. đóng gói chắc chắn',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm',
#     'AspectTerms': ['đẹp', 'nguyên seal']},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': ['đóng gói chắc chắn']}]},
#  {'GeneralFeedbackID': 19787529,
#   'ID': 112,
#   'Content': 'sản phẩm rất tốt, giá cả hợp lý, xài rất mượt, chơi game nặng thì hơi nhanh nóng máy còn dùng bt thì ok, pin dùng được lâu',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm',
#     'AspectTerms': ['tốt', 'hợp lý', 'mượt']},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': ['ok']}]},
#  {'GeneralFeedbackID': 16034715,
#   'ID': 113,
#   'Content': 'hàng chuẩn chính hãng',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm', 'AspectTerms': []},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 14717339,
#   'ID': 114,
#   'Content': 'giao hàng nhanh hàng za chính hãng ipad ko có mã vna toàn cầu nhé mọi người',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm',
#     'AspectTerms': ['chính hãng', 'ipad']},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': ['giao hàng nhanh']}]},
#  {'GeneralFeedbackID': 17324713,
#   'ID': 115,
#   'Content': 'chất lượng uy tín',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm',
#     'AspectTerms': ['chất', 'lượng', 'uy', 'tín']},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 19713917,
#   'ID': 116,
#   'Content': 'hàng nhận tốt.',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm', 'AspectTerms': []},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 18103689,
#   'ID': 117,
#   'Content': 'hàng chuẩn chính hãng, giá lại đang tốt',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm',
#     'AspectTerms': ['chính hãng', 'giá lại']},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 14957288,
#   'ID': 118,
#   'Content': 'giao hàng nhanh, sp như mong đợi',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm',
#     'AspectTerms': ['giao hàng nhanh', 'sp như mong đợi']},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 14975325,
#   'ID': 119,
#   'Content': 'tikinow giao hàng cực nhanh và cẩn thận. mua ipad ở tiki 3 lần rồi lần nào cũng ưng. hàng chính hãng thì cứ chỗ nào rẻ mua thôi. highly recommended!',
#   'Aspects': [{'AspectCategory': 'Về Dịch Vụ',
#     'AspectTerms': ['giao hàng cực nhanh', 'cẩn thận']},
#    {'AspectCategory': 'Về Sản Phẩm', 'AspectTerms': ['hàng chính hãng']}]},
#  {'GeneralFeedbackID': 16905688,
#   'ID': 121,
#   'Content': 'ok',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm', 'AspectTerms': []},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 14687364,
#   'ID': 122,
#   'Content': 'giao hàng nhanh, sản phẩm tốt',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm',
#     'AspectTerms': ['giao hàng nhanh', 'sản phẩm tốt']},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 16075762,
#   'ID': 123,
#   'Content': 'tiki giao hàng quá nhanh. giá rẻ hơn bên ngoài rất nhiều.',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm',
#     'AspectTerms': ['giao hàng quá nhanh', 'giá rẻ']},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 19534234,
#   'ID': 124,
#   'Content': 'gia ok',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm', 'AspectTerms': []},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 19534311,
#   'ID': 125,
#   'Content': 'giao hàng nhanh',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm', 'AspectTerms': []},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 19878804,
#   'ID': 126,
#   'Content': 'giao nhanh đến bất ngờ, shiper thân thiện. mua đồ giá trị cao trên tiki khá tin tưởng',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm',
#     'AspectTerms': ['giao nhanh', 'đến bất ngờ']},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': ['shipper thân thiện']}]},
#  {'GeneralFeedbackID': 15127419,
#   'ID': 127,
#   'Content': 'vừa nhận chưa thấy lỗi gì . tiki đã kích hoạt bảo hành trước 1 ngày khi nhận máy',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm',
#     'AspectTerms': ['chưa thấy lỗi gì']},
#    {'AspectCategory': 'Về Dịch Vụ',
#     'AspectTerms': ['kích hoạt bảo hành trước 1 ngày khi nhận máy']}]},
#  {'GeneralFeedbackID': 15141928,
#   'ID': 128,
#   'Content': 'ok',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm', 'AspectTerms': []},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 14775666,
#   'ID': 130,
#   'Content': 'ok',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm', 'AspectTerms': []},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 15507321,
#   'ID': 131,
#   'Content': 'sản phẩm tốt phù hợp cho học tập và giải trí',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm',
#     'AspectTerms': ['tốt', 'phù hợp cho học tập và giải trí']},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 16478785,
#   'ID': 132,
#   'Content': 'rất tốt',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm', 'AspectTerms': []},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 19577618,
#   'ID': 133,
#   'Content': 'phù hợp với hssv',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm', 'AspectTerms': []},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 18609650,
#   'ID': 134,
#   'Content': 'nên mua. giá rẻ. dùng khá ổn',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm',
#     'AspectTerms': ['nên mua', 'giá rẻ']},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': ['dùng khá ổn']}]},
#  {'GeneralFeedbackID': 16258652,
#   'ID': 135,
#   'Content': 'giao hàng siêu nhanh , rất tốt',
#   'Aspects': [{'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': ['siêu nhanh']},
#    {'AspectCategory': 'Về Sản Phẩm', 'AspectTerms': ['rất tốt']}]},
#  {'GeneralFeedbackID': 14542601,
#   'ID': 136,
#   'Content': 'hàng full bọc,chất lượng khỏi bàn!',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm',
#     'AspectTerms': ['full', 'bọc', 'chất lượng']},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': ['khỏi bàn']}]},
#  {'GeneralFeedbackID': 19211925,
#   'ID': 138,
#   'Content': 'hàng mới tốt , giao nhanh',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm', 'AspectTerms': ['tốt']},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': ['giao nhanh']}]},
#  {'GeneralFeedbackID': 18467515,
#   'ID': 139,
#   'Content': 'sử dụng oki',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm', 'AspectTerms': []},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 14820146,
#   'ID': 140,
#   'Content': 'sản phẩm đẹp đóng gói cẩn thận, giao hàng nhanh. trải nghiệm rất tốt',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm',
#     'AspectTerms': ['đẹp', 'đóng gói cẩn thận']},
#    {'AspectCategory': 'Về Dịch Vụ',
#     'AspectTerms': ['giao hàng nhanh', 'trải nghiệm rất tốt']}]},
#  {'GeneralFeedbackID': 15227151,
#   'ID': 141,
#   'Content': 'good. nguyên seal tự khui. mà đang thắc mắc tại sao mã máy là zaa',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm',
#     'AspectTerms': ['tự khui', 'nguyên seal']},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': ['mã máy là zaa']}]},
#  {'GeneralFeedbackID': 15119251,
#   'ID': 142,
#   'Content': 'ok giao hàng nhanh',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm',
#     'AspectTerms': ['giao hàng nhanh']},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 15120765,
#   'ID': 143,
#   'Content': 'giao hàng nhanh, sản phẩm tốt',
#   'Aspects': [{'AspectCategory': 'Về Dịch Vụ',
#     'AspectTerms': ['giao hàng nhanh']},
#    {'AspectCategory': 'Về Sản Phẩm', 'AspectTerms': ['sản phẩm tốt']}]},
#  {'GeneralFeedbackID': 19133911,
#   'ID': 144,
#   'Content': 'sử dụng tốt',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm', 'AspectTerms': []},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 14844304,
#   'ID': 145,
#   'Content': 'sản phẩm đúng mô tả',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm', 'AspectTerms': ['đúng mô tả']},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 15931628,
#   'ID': 146,
#   'Content': 'hàng đóng gói kỹ, ship nhanh, còn nguyên seal kiện và hộp không bị cấn móp, mua tiki là an tâm nhất rồi',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm',
#     'AspectTerms': ['đóng gói kỹ',
#      'ship nhanh',
#      'còn nguyên seal kiện',
#      'hộp không bị cấn móp']},
#    {'AspectCategory': 'Về Dịch Vụ',
#     'AspectTerms': ['mua tiki là an tâm nhất rồi']}]},
#  {'GeneralFeedbackID': 15511462,
#   'ID': 147,
#   'Content': 'good',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm', 'AspectTerms': []},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 17612200,
#   'ID': 148,
#   'Content': 'sản phẩm nguyên seal, giao hàng nhanh và được kiểm hàng trước.',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm',
#     'AspectTerms': ['nguyên seal', 'giao hàng nhanh', 'kiểm hàng trước']},
#    {'AspectCategory': 'Về Dịch Vụ',
#     'AspectTerms': ['giao hàng nhanh', 'kiểm hàng trước']}]},
#  {'GeneralFeedbackID': 19078093,
#   'ID': 149,
#   'Content': 'chính hãng, giao nhanh',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm',
#     'AspectTerms': ['chính hãng', 'giao nhanh']},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 15045687,
#   'ID': 150,
#   'Content': 'sản phẩm chính hãng, dùng tốt',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm',
#     'AspectTerms': ['chính hãng', 'dùng tốt']},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 18885893,
#   'ID': 151,
#   'Content': 'sản phẩm giao nhanh, giá thành tốt',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm',
#     'AspectTerms': ['giao nhanh', 'giá thành tốt']},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 16134233,
#   'ID': 152,
#   'Content': 'hộp hơi méo 1 chút',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm', 'AspectTerms': ['hơi', 'méo']},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 19452296,
#   'ID': 153,
#   'Content': 'máy tốt',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm', 'AspectTerms': []},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 16746082,
#   'ID': 154,
#   'Content': 'tốt lắm',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm', 'AspectTerms': []},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 15310591,
#   'ID': 155,
#   'Content': 'hàng đẹp, giao nhanh.',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm', 'AspectTerms': ['đẹp']},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': ['nhanh']}]},
#  {'GeneralFeedbackID': 18745037,
#   'ID': 156,
#   'Content': 'hàng chính hãng, giao hàng nhanh',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm', 'AspectTerms': ['chính hãng']},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': ['giao hàng nhanh']}]},
#  {'GeneralFeedbackID': 15297165,
#   'ID': 157,
#   'Content': 'hàng đúng cam kết, mới tinh, xài tốt.',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm',
#     'AspectTerms': ['đúng', 'mới tinh', 'xài tốt']},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 15305710,
#   'ID': 158,
#   'Content': 'khá tuyệt',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm', 'AspectTerms': []},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 17106768,
#   'ID': 159,
#   'Content': 'hàng quá ổn',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm', 'AspectTerms': []},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 18528305,
#   'ID': 160,
#   'Content': 'hàng đúng mô tả',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm', 'AspectTerms': []},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 16457346,
#   'ID': 161,
#   'Content': 'sản phẩm tikinow luôn chất lượng!',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm', 'AspectTerms': ['chất lượng']},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 16116693,
#   'ID': 162,
#   'Content': 'sp tốt',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm', 'AspectTerms': []},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 19821194,
#   'ID': 163,
#   'Content': 'giao hàng nhanh, đóng gói cẩn thận',
#   'Aspects': [{'AspectCategory': 'Về Dịch Vụ',
#     'AspectTerms': ['giao hàng nhanh', 'đóng gói cẩn thận']}]},
#  {'GeneralFeedbackID': 19926458,
#   'ID': 164,
#   'Content': 'khá đẹp tạm thời đánh giá sau 1 tuần quay lại cập nhật',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm', 'AspectTerms': []},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 16552143,
#   'ID': 165,
#   'Content': 'ok',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm', 'AspectTerms': []},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 15204805,
#   'ID': 166,
#   'Content': 'sản phẩm như mô tả. sử dụng tốt',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm',
#     'AspectTerms': ['mô tả', 'sử dụng']},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 15343715,
#   'ID': 167,
#   'Content': 'khá oke',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm', 'AspectTerms': []},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 18222235,
#   'ID': 168,
#   'Content': 'giao hàng nhanh, hàng chính hãng',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm',
#     'AspectTerms': ['hàng chính hãng']},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': ['giao hàng nhanh']}]},
#  {'GeneralFeedbackID': 17456115,
#   'ID': 169,
#   'Content': 'đồ chính hãng.máy không có gì phải bàn',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm', 'AspectTerms': ['chính hãng']},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 19674647,
#   'ID': 170,
#   'Content': 'đóng gói ok sản phẩm rất tốt. nên mua ở tiki uy tín nha mn',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm',
#     'AspectTerms': ['đóng gói', 'sản phẩm']},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': ['mua ở tiki uy tín']}]},
#  {'GeneralFeedbackID': 13625495,
#   'ID': 171,
#   'Content': 'good, hàng chính hãng apple nguyên seal',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm',
#     'AspectTerms': ['chính hãng', 'apple', 'nguyên seal']},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 18186360,
#   'ID': 172,
#   'Content': 'chuẩn hàng. đóng gói tốt, shiper thân thiện và cẩn trọng. cảm ơn tiki , cảm ơn shiper',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm',
#     'AspectTerms': ['chuẩn hàng', 'đóng gói tốt']},
#    {'AspectCategory': 'Về Dịch Vụ',
#     'AspectTerms': ['thân thiện', 'cẩn trọng']}]},
#  {'GeneralFeedbackID': 15476791,
#   'ID': 173,
#   'Content': 'chính hãng, đẹp!',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm',
#     'AspectTerms': ['chính hãng', 'đẹp']},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 18962658,
#   'ID': 174,
#   'Content': 'ok ngon',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm', 'AspectTerms': []},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 15260519,
#   'ID': 175,
#   'Content': 'ngon trong tầm giá, giao hàng nhanh',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm',
#     'AspectTerms': ['ngon', 'tầm giá']},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': ['giao hàng nhanh']}]},
#  {'GeneralFeedbackID': 18280555,
#   'ID': 176,
#   'Content': 'đẹp rẻ tuyệt vời',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm', 'AspectTerms': ['đẹp', 'rẻ']},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': ['tuyệt vời']}]},
#  {'GeneralFeedbackID': 16963090,
#   'ID': 177,
#   'Content': 'ok',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm', 'AspectTerms': []},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 17383559,
#   'ID': 178,
#   'Content': 'dung lượng pin ok, cảm ứng khá tốt trong tầm giá',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm',
#     'AspectTerms': ['dung lượng pin', 'cảm ứng']},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 19872848,
#   'ID': 179,
#   'Content': 'ok',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm', 'AspectTerms': []},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 18375806,
#   'ID': 180,
#   'Content': 'ok sản phẩm dùng tốt',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm',
#     'AspectTerms': ['sản phẩm', 'dùng tốt']},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 15209363,
#   'ID': 181,
#   'Content': 'ok',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm', 'AspectTerms': []},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 18736248,
#   'ID': 182,
#   'Content': 'đẹp',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm', 'AspectTerms': []},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 15128293,
#   'ID': 183,
#   'Content': 'máy nguyên seal, lần đầu mua hàng điện tử vs giá trị cao qua mạng cũng khá lo, nhưng thấy nhiều ng và nx tốt nên cũng liều 1 lần vì trời mưa rét nên lười ra shop mua.',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm',
#     'AspectTerms': ['máy nguyên seal']},
#    {'AspectCategory': 'Về Dịch Vụ',
#     'AspectTerms': ['mua hàng điện tử qua mạng']}]},
#  {'GeneralFeedbackID': 16239045,
#   'ID': 184,
#   'Content': 'good',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm', 'AspectTerms': []},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 15342097,
#   'ID': 185,
#   'Content': 'chưa đánh giá gì hết tính out ra chụp hình thì đã tự nhảy 5 sao, ghét quá sửa lại 1 sao.',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm',
#     'AspectTerms': ['tính', 'out', 'ra', 'chụp', 'hình']},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': ['sửa']}]},
#  {'GeneralFeedbackID': 15213705,
#   'ID': 186,
#   'Content': 'giao hàng nhanh chóng, đóng gói rất chắc chắn, hàng mới nguyên zin, vừa acctive , giao hàng nhanh chóng, đóng gói rất chắc chắn, hàng mới nguyên zin, vừa acctive ,',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm',
#     'AspectTerms': ['giao hàng nhanh chóng',
#      'đóng gói rất chắc chắn',
#      'hàng mới nguyên zin']},
#    {'AspectCategory': 'Về Dịch Vụ',
#     'AspectTerms': ['giao hàng nhanh chóng', 'đóng gói rất chắc chắn']}]},
#  {'GeneralFeedbackID': 18993544,
#   'ID': 187,
#   'Content': 'k hiểu sao, tiki đóng gói rất cẩn thận, nhưng hộp vẫn bị móp 3 góc.',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm', 'AspectTerms': ['hộp', 'móp']},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': ['đóng gói cẩn thận']}]},
#  {'GeneralFeedbackID': 14672418,
#   'ID': 188,
# ...
#  {'GeneralFeedbackID': 14804495,
#   'ID': 1586,
#   'Content': 'giao hàng nhanh hàng chính hãng giá quá okiii sẽ ủng hộ',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm',
#     'AspectTerms': ['hàng chính hãng']},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': ['giao hàng nhanh']}]},
#  {'GeneralFeedbackID': 15670573,
#   'ID': 1587,
#   'Content': 'hàng đóng gói cẩn thận, giao nhanh. nói chung mua đồ giá trị cao từ tiki official thì rất yên tâm vì có quy trình giao hàng riêng rất tốt',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm',
#     'AspectTerms': ['đóng gói cẩn thận', 'giao nhanh']},
#    {'AspectCategory': 'Về Dịch Vụ',
#     'AspectTerms': ['quy trình giao hàng riêng rất tốt']}]},
#  {'GeneralFeedbackID': 13548540,
#   'ID': 1588,
#   'Content': 'hàng chuẩn',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm', 'AspectTerms': []},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 15874732,
#   'ID': 1590,
#   'Content': 'ok',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm', 'AspectTerms': []},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 19344905,
#   'ID': 1592,
#   'Content': 'đánh giá không tính điểm đơn vị vận chuyển giao hàng chậm, chuyển nhầm kho tới tui rất mất thời gian',
#   'Aspects': [{'AspectCategory': 'Về Dịch Vụ',
#     'AspectTerms': ['giao hàng chậm', 'chuyển nhầm kho']}]},
#  {'GeneralFeedbackID': 14115981,
#   'ID': 1593,
#   'Content': 'giao hàng như tên lửa, tuyệt vời!!!',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm', 'AspectTerms': []},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 18243865,
#   'ID': 1594,
#   'Content': 'ok',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm', 'AspectTerms': []},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 13290080,
#   'ID': 1595,
#   'Content': 'giao hàng quá nhanh',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm', 'AspectTerms': []},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 16522226,
#   'ID': 1596,
#   'Content': 'máy đẹp. khung nhôm nên rất nhẹ cầm nắm dễ chịu không như máy khung thép. pin lâu hơn hẳn so với các đời trước. cam chụp đêm rất ổn.',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm',
#     'AspectTerms': ['khung nhôm', 'pin lâu']},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 13763488,
#   'ID': 1597,
#   'Content': 'hàng chính hãng, tốt',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm',
#     'AspectTerms': ['chính hãng', 'tốt']},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 14413565,
#   'ID': 1599,
#   'Content': 'giao hàng nhanh. hàng đẹp chuẩn 5 sao.',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm',
#     'AspectTerms': ['hàng đẹp', 'chính xác']},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': ['giao hàng nhanh']}]},
#  {'GeneralFeedbackID': 14030158,
#   'ID': 1600,
#   'Content': 'đỉnh thật sự. giá tốt, giao nhanh',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm',
#     'AspectTerms': ['đỉnh', 'giá tốt']},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': ['giao nhanh']}]},
#  {'GeneralFeedbackID': 13583008,
#   'ID': 1601,
#   'Content': 'hàng giao hơi lâu. mình đợi 1 tuần sau hạn giao hàng ban đầu. săn đc sales black friday nên giá tốt. hàng ổn. đã test hiện mọi thứ vẫn ok',
#   'Aspects': [{'AspectCategory': 'Về Dịch Vụ',
#     'AspectTerms': ['hàng giao hơi lâu',
#      'mình đợi 1 tuần sau hạn giao hàng ban đầu']},
#    {'AspectCategory': 'Về Sản Phẩm',
#     'AspectTerms': ['giá tốt', 'hàng ổn', 'đã test hiện mọi thứ vẫn ok']}]},
#  {'GeneralFeedbackID': 19854801,
#   'ID': 1602,
#   'Content': 'good, giao nhanh và hàng tốt',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm', 'AspectTerms': ['tốt']},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': ['nhanh']}]},
#  {'GeneralFeedbackID': 14192220,
#   'ID': 1603,
#   'Content': 'máy đẹp mà tiki giao chậm, chăm sóc khách hàng mình thấy chưa tốt, nhân viên tiếp nhận thông tin mà ko có action gì hỗ trợ khách',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm',
#     'AspectTerms': ['máy đẹp', 'tiki giao chậm']},
#    {'AspectCategory': 'Về Dịch Vụ',
#     'AspectTerms': ['chăm sóc khách hàng chưa tốt',
#      'nhân viên tiếp nhận thông tin mà ko có action gì hỗ trợ khách']}]},
#  {'GeneralFeedbackID': 15270299,
#   'ID': 1604,
#   'Content': 'tiki now giao hàng nhanh, sản phẩm chính hãng. đã mua tiki cái iphone thứ 3',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm', 'AspectTerms': ['chính hãng']},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': ['giao hàng nhanh']}]},
#  {'GeneralFeedbackID': 13934519,
#   'ID': 1605,
#   'Content': 'giao hàng cực nhanh luôn ạ. mình đặt tối t7 mà thứ 2 tiki đã giao dù mình chỉ chọn gh tiêu chuẩn thôi. hàng nguyên seal chuẩn vna ạ.',
#   'Aspects': [{'AspectCategory': 'Về Dịch Vụ',
#     'AspectTerms': ['giao hàng cực nhanh',
#      'đã giao dù mình chỉ chọn gh tiêu chuẩn']},
#    {'AspectCategory': 'Về Sản Phẩm',
#     'AspectTerms': ['hàng nguyên seal chuẩn vna']}]},
#  {'GeneralFeedbackID': 18213809,
#   'ID': 1606,
#   'Content': 'hàng chính hãng, giao hàng nhanh. giá cũng tốt',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm',
#     'AspectTerms': ['chính hãng', 'giáo hàng nhanh']},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': ['giao hàng nhanh']}]},
#  {'GeneralFeedbackID': 13264204,
#   'ID': 1607,
#   'Content': 'giao hàng nhanh. sản phẩm giá trị cao nhưng đóng hộp đơn giản quá. lúc mình nhận được thì hộp ngoài đã móp méo rồi cũng may ko ảnh hưởng sản phẩm. tiki nên đóng hộp cứng cáp hơn nữa',
#   'Aspects': [{'AspectCategory': 'Về Dịch Vụ',
#     'AspectTerms': ['giao hàng nhanh']},
#    {'AspectCategory': 'Về Sản Phẩm',
#     'AspectTerms': ['sản phẩm giá trị cao',
#      'đóng hộp đơn giản quá',
#      'hộp ngoài đã móp méo rồi']}]},
#  {'GeneralFeedbackID': 15185154,
#   'ID': 1609,
#   'Content': 'ok lắm',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm', 'AspectTerms': []},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 18548031,
#   'ID': 1611,
#   'Content': 'đúng miêu tả, nguyên seal',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm',
#     'AspectTerms': ['đúng miêu tả', 'nguyên seal']},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 13819109,
#   'ID': 1612,
#   'Content': 'hàng chính hãng',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm', 'AspectTerms': []},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 13404891,
#   'ID': 1613,
#   'Content': 'good!',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm', 'AspectTerms': []},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 16323601,
#   'ID': 1614,
#   'Content': 'sản phẩm quá ok. tuyệt vời!',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm',
#     'AspectTerms': ['quá', 'tuyệt vời']},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 14197010,
#   'ID': 1615,
#   'Content': 'giao hàng nhanh',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm', 'AspectTerms': []},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 14313139,
#   'ID': 1616,
#   'Content': 'điện thoại ổn',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm', 'AspectTerms': []},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 19782913,
#   'ID': 1617,
#   'Content': 'hàng như mô tả, đóng gói kĩ càng, giao đúng hạn.',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm',
#     'AspectTerms': ['hàng như mô tả', 'đóng gói kĩ càng']},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': ['giao đúng hạn']}]},
#  {'GeneralFeedbackID': 15934113,
#   'ID': 1618,
#   'Content': 'máy dùng tốt. mua của tiki hàng vna là rất yên tâm rồi',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm', 'AspectTerms': ['dùng tốt']},
#    {'AspectCategory': 'Về Dịch Vụ',
#     'AspectTerms': ['tiki hàng vna là rất yên tâm rồi']}]},
#  {'GeneralFeedbackID': 14715334,
#   'ID': 1619,
#   'Content': 'giao hàng nhanh như cơn gió. có thêm tem tiki nữa nên rất đảm bảo. mình đã mua rất nhiều đồ điện tử của tiki nên rất an tâm, giá tiki lại tốt nữa. chính sách bảo hành của tiki thì khỏi phải bàn nhé',
#   'Aspects': [{'AspectCategory': 'Về Dịch Vụ',
#     'AspectTerms': ['giao hàng nhanh', 'có thêm tem tiki']},
#    {'AspectCategory': 'Về Sản Phẩm',
#     'AspectTerms': ['giá tốt', 'chính sách bảo hành']}]},
#  {'GeneralFeedbackID': 14100852,
#   'ID': 1620,
#   'Content': 'hài lòng',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm', 'AspectTerms': []},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 19243640,
#   'ID': 1621,
#   'Content': 'khung viền màn hình không thật sự sát với màn hình khi đem so với hàng còn nguyên seal của cellphones.',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm',
#     'AspectTerms': ['sản phẩm', 'hàng']},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 13765853,
#   'ID': 1622,
#   'Content': 'dùng 12 64gb ko đủ nên lên 13 256gb cho dùng khỏi lăn tăn',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm',
#     'AspectTerms': ['sản phẩm', 'đủ']},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 14754138,
#   'ID': 1623,
#   'Content': 'hàng chính hãng',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm', 'AspectTerms': []},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 12861123,
#   'ID': 1624,
#   'Content': 'quả táo khỏi phải nói giao hàng nhanh hơn dự kiến chưa đc dùng nên k có gì để bàn về chất lượng sản phẩm',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm', 'AspectTerms': ['chất lượng']},
#    {'AspectCategory': 'Về Dịch Vụ',
#     'AspectTerms': ['giao hàng nhanh hơn dự kiến']}]},
#  {'GeneralFeedbackID': 13026048,
#   'ID': 1628,
#   'Content': 'giá tốt nếu mua bằng thẻ',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm', 'AspectTerms': []},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 17407253,
#   'ID': 1630,
#   'Content': 'sóng có vẻ yếu hơn iphone cũ',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm',
#     'AspectTerms': ['sản phẩm', 'điện thoại']},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 18699511,
#   'ID': 1631,
#   'Content': 'sp tốt',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm', 'AspectTerms': []},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 14575709,
#   'ID': 1632,
#   'Content': 'ốp lưng và kính đều nhìn tốt. thêm ốp vào cầm đằm tay',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm',
#     'AspectTerms': ['ốp lưng', 'kính']},
#    {'AspectCategory': 'Về Dịch Vụ',
#     'AspectTerms': ['thêm ốp vào cầm đằm tay']}]},
#  {'GeneralFeedbackID': 16440111,
#   'ID': 1633,
#   'Content': 'ok',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm', 'AspectTerms': []},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 13423325,
#   'ID': 1634,
#   'Content': 'quá chất lượng',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm', 'AspectTerms': []},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 16974897,
#   'ID': 1635,
#   'Content': 'sản phẩm chất lượng. giao hàng nhanh. đúng màu đặt hàng',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm', 'AspectTerms': ['chất lượng']},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': ['giao hàng nhanh']}]},
#  {'GeneralFeedbackID': 15434453,
#   'ID': 1636,
#   'Content': 'giao nhanh, sản phẩm ko lỗi, hộp nguyên đẹp.',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm',
#     'AspectTerms': ['Giao nhanh', 'Sản phẩm không lỗi']},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': ['Hộp nguyên đẹp']}]},
#  {'GeneralFeedbackID': 14095052,
#   'ID': 1637,
#   'Content': 'lần đầu mua điện thoại trên tiki mình cũng hơi lo lắng nhưng nhận hàng rất ok,đến nay sử dụng hơn 10 ngày mình rất hài lòng, giá mua tốt hơn ở cửa hàng nhiều. thanks tiki.',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm',
#     'AspectTerms': ['hài lòng', 'giá tốt']},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': ['nhận hàng ok']}]},
#  {'GeneralFeedbackID': 18693080,
#   'ID': 1638,
#   'Content': 'giao hàng nhanh mặc dù đang trong kì nghỉ tết. đóng gói cẩn thận. hàng nguyên seal apple chưa kích hoạt.',
#   'Aspects': [{'AspectCategory': 'Về Dịch Vụ',
#     'AspectTerms': ['giao hàng nhanh', 'đóng gói cẩn thận']},
#    {'AspectCategory': 'Về Sản Phẩm',
#     'AspectTerms': ['hàng nguyên seal apple chưa kích hoạt']}]},
#  {'GeneralFeedbackID': 19554425,
#   'ID': 1639,
#   'Content': 'giao nhanh, máy đẹp , đóng gói chắc chắn',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm',
#     'AspectTerms': ['giao nhanh', 'máy đẹp']},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': ['đóng gói chắc chắn']}]},
#  {'GeneralFeedbackID': 13689657,
#   'ID': 1640,
#   'Content': 'giao nhanh, gói kỹ, cẩn thận.',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm',
#     'AspectTerms': ['giao nhanh', 'gói kỹ']},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': ['cẩn thận']}]},
#  {'GeneralFeedbackID': 13286980,
#   'ID': 1641,
#   'Content': 'màu hồng đẹp',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm', 'AspectTerms': []},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 13409967,
#   'ID': 1642,
#   'Content': 'đã nhận đc hàng nhanh chóng,đặt tầm 1h là giao hàng còn đc áp mã km tới 1tr5',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm',
#     'AspectTerms': ['nhanh_nhap_hang']},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': ['tong_hop_dich_vu']}]},
#  {'GeneralFeedbackID': 15546616,
#   'ID': 1643,
#   'Content': 'hàng đc đóng gói kỹ lưỡng, nhận hàng phải có otp',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm',
#     'AspectTerms': ['đóng gói kỹ lưỡng']},
#    {'AspectCategory': 'Về Dịch Vụ',
#     'AspectTerms': ['nhan hang phai co otp']}]},
#  {'GeneralFeedbackID': 13569515,
#   'ID': 1645,
#   'Content': 'đúng chuẩn, nguyên seal',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm', 'AspectTerms': []},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 14196278,
#   'ID': 1646,
#   'Content': 'giao hàng nhanh, xài ok',
#   'Aspects': [{'AspectCategory': 'Về Dịch Vụ',
#     'AspectTerms': ['giao hàng nhanh']},
#    {'AspectCategory': 'Về Sản Phẩm', 'AspectTerms': ['xài ok']}]},
#  {'GeneralFeedbackID': 20017539,
#   'ID': 1647,
#   'Content': 'mua về cho nhỏ cháu xài, kiu nó chụp hình quài mà nó quên nên chụp cái túi tặng, sản phẩm chính hãng còn nguyên seal chưa bị bóc, xài quá ổn áp luôn, màu đẹp.',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm',
#     'AspectTerms': ['chính hãng', 'nguyên seal', 'ổn áp']},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': ['tặng', 'hình quài']}]},
#  {'GeneralFeedbackID': 13259654,
#   'ID': 1648,
#   'Content': 'giao hàng nhanh, luôn tin tưởng hàng điện tử của tiki the best service the best quality',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm',
#     'AspectTerms': ['giao hàng nhanh', 'hàng điện tử']},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': ['the best service']}]},
#  {'GeneralFeedbackID': 15812243,
#   'ID': 1649,
#   'Content': 'tâts cả đều ổn',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm', 'AspectTerms': []},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 13285375,
#   'ID': 1650,
#   'Content': 'ok',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm', 'AspectTerms': []},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 13317007,
#   'ID': 1652,
#   'Content': 'đẹp',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm', 'AspectTerms': []},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 13494182,
#   'ID': 1653,
#   'Content': 'hàng chính hãng, giao hàng nhanh',
#   'Aspects': [{'AspectCategory': 'Về Sản Phẩm',
#     'AspectTerms': ['chính hãng', 'giao hàng nhanh']},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': []}]},
#  {'GeneralFeedbackID': 13507803,
#   'ID': 1654,
#   'Content': 'khi giao hàng tiki sẽ gửi cho bạn 1 mặc code qua tin nhắn chỉ khi bạn đọc đúng code thì shipper mới giao hàng nên ko lo mất hàng',
#   'Aspects': [{'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': ['giao hàng']},
#    {'AspectCategory': 'Về Dịch Vụ', 'AspectTerms': ['mất hàng']}]},
#  ...]

# %%
print("\n=== Performing Sentiment Analysis ===")
final_results = []
pos_count = 0
neg_count = 0
neu_count = 0

for feedback in tqdm(processed_results, desc="Analyzing sentiment"):
    content = feedback['Content']
    results = []
    
    for aspect in feedback['Aspects']:
        if not aspect.get('AspectTerms'):
            results.append({
                "AspectCategory": aspect['AspectCategory'],
                "AspectTerms": [],
                "Polarity": None,
                "DominantScore": None
            })
        else:
            terms = aspect['AspectTerms']
            if isinstance(terms, str):
                terms = [terms]
                
            for term in terms:
                start = max(0, content.find(term) - 20)
                end = min(len(content), content.find(term) + len(term) + 20)
                context = content[start:end]
                
                sentiment = analyze_sentiment(context)
                dominant_sentiment = get_dominant_sentiment(sentiment)
                dominant_score = round(sentiment[dominant_sentiment], 3)
                polarity = sentiment_to_polarity(dominant_sentiment)
                
                if polarity == "POS":
                    pos_count += 1
                elif polarity == "NEG":
                    neg_count += 1
                else:
                    neu_count += 1
                    
                results.append({
                    "AspectCategory": aspect['AspectCategory'],
                    "AspectTerms": term,
                    "Polarity": polarity,
                    "DominantScore": dominant_score
                })

    processed_feedback = {
        "GeneralFeedbackID": feedback['GeneralFeedbackID'],
        "ID": feedback['ID'],
        "Content": content,
        "Aspects": results
    }
    final_results.append(processed_feedback)

print(f'[INFO] Sentiment Distribution:')
print(f'      Positive: {pos_count:,} aspects')
print(f'      Negative: {neg_count:,} aspects') 
print(f'      Neutral: {neu_count:,} aspects')
print(f'[INFO] Completed sentiment analysis for {len(final_results):,} entries')

# Save results
print("\n=== Saving Results ===")
with open('warehouse/feedback/ABSA_CustomerSatisfaction.json', 'w', encoding='utf-8-sig') as f:
   json.dump(final_results, f, ensure_ascii=False, indent=2)
print(f'[SUCCESS] Saved {len(final_results):,} processed entries to ABSA_CustomerSatisfaction.json')
print("\n=== Pipeline Complete ===")
# Out:
# === Performing Sentiment Analysis ===
# Analyzing sentiment:   0%|          | 0/2502 [00:00<?, ?it/s]
# [INFO] Sentiment Distribution:
#       Positive: 3,811 aspects
#       Negative: 785 aspects
#       Neutral: 726 aspects
# [INFO] Completed sentiment analysis for 2,502 entries
#
# === Saving Results ===
# [SUCCESS] Saved 2,502 processed entries to ABSA_CustomerSatisfaction.json
#
# === Pipeline Complete ===
