# %%
import json
import torch
from transformers import T5ForConditionalGeneration, T5Tokenizer
from datasets import Dataset
from sklearn.metrics import precision_score, recall_score, f1_score

# %%
# Load the trained model and tokenizer
def load_model_and_tokenizer(model_path):
    model = T5ForConditionalGeneration.from_pretrained(model_path)
    tokenizer = T5Tokenizer.from_pretrained(model_path)
    return model, tokenizer

# %%
# Load the test data (in the same format as the training data)
def load_test_data(json_file_path):
    with open(json_file_path, 'r', encoding='utf-8-sig') as file:
        data = json.load(file)
    
    input_lines = []
    label_lines = []
    for entry in data:
        # Append the 'Content' field to input_lines
        input_lines.append(entry['Content'])
        
        # Append the 'Aspects' field (concatenated terms) to label_lines
        aspects = [term for aspect in entry['Aspects'] for term in aspect['AspectTerms']]
        label_lines.append(' '.join(aspects))  # Join the aspect terms into a single string
    
    return input_lines, label_lines

# %%
# Preprocess the input text for the model
def preprocess_input(input_texts, tokenizer, max_length=128):
    return tokenizer(input_texts, return_tensors="pt", truncation=True, padding=True, max_length=max_length)

# %%
# Run inference using the trained model
def generate_predictions(input_texts, model, tokenizer, max_length=128, num_beams=4):
    model.eval()  # Set model to evaluation mode
    inputs = preprocess_input(input_texts, tokenizer, max_length)

    # Perform inference with beam search for better predictions
    with torch.no_grad():
        outputs = model.generate(
            input_ids=inputs['input_ids'],
            attention_mask=inputs['attention_mask'],
            max_length=max_length,
            num_beams=num_beams,
            early_stopping=True
        )

    # Decode the output tokens to text
    decoded_outputs = [tokenizer.decode(output, skip_special_tokens=True) for output in outputs]
    return decoded_outputs

# %%
# Evaluate the predictions with ground truth labels (if available)
def evaluate_predictions(predicted_aspects, ground_truth_aspects):
    all_possible_aspects = set()  # Set to store all possible aspects in the test data

    # Collect all unique aspects
    for aspects in ground_truth_aspects:
        all_possible_aspects.update(aspects.split())

    all_possible_aspects = list(all_possible_aspects)  # Convert set to list

    # Vectorize the aspect terms (binary vectors)
    def binary_vectorize(aspect_list, all_possible_aspects):
        return [1 if aspect in aspect_list else 0 for aspect in all_possible_aspects]

    y_true = [binary_vectorize(gt.split(), all_possible_aspects) for gt in ground_truth_aspects]
    y_pred = [binary_vectorize(pred.split(), all_possible_aspects) for pred in predicted_aspects]

    precision = precision_score(y_true, y_pred, average='macro')
    recall = recall_score(y_true, y_pred, average='macro')
    f1 = f1_score(y_true, y_pred, average='macro')

    print(f"Precision: {precision:.4f}")
    print(f"Recall: {recall:.4f}")
    print(f"F1 Score: {f1:.4f}")

# %%
# Test module function that loads the model, test data, performs inference, and evaluates
def test_model(model_path, test_json_file):
    # Step 1: Load the trained model and tokenizer
    model, tokenizer = load_model_and_tokenizer(model_path)

    # Step 2: Load the test data (in the same JSON format as training data)
    test_inputs, ground_truth_aspects = load_test_data(test_json_file)

    # Step 3: Generate predictions for the test data
    predicted_aspects = generate_predictions(test_inputs, model, tokenizer)

    # Step 4: Print the predictions
    for i, input_text in enumerate(test_inputs):
        print(f"Input: {input_text}")
        print(f"Predicted Aspects: {predicted_aspects[i]}")
        print(f"Ground Truth Aspects: {ground_truth_aspects[i]}")
        print()

    # Step 5: Evaluate the predictions
    evaluate_predictions(predicted_aspects, ground_truth_aspects)

# %%
model_path = "FlexiModel" 
test_json_file = "vncorenlp/label_subset.json" 
    
test_model(model_path, test_json_file)
# Out:
# Input: giao hàng rất muộn
# Predicted Aspects: giao mun
# Ground Truth Aspects: giao hàng
#
# Input: ram chạy tốt
# Predicted Aspects: ram
# Ground Truth Aspects: ram
#
# Input: quá ok
# Predicted Aspects:
# Ground Truth Aspects:
#
# Input: đẹp
# Predicted Aspects:
# Ground Truth Aspects:
#
# Input: sản phẩm tốt
# Predicted Aspects: sn phm
# Ground Truth Aspects: sản phẩm
#
# Input: mua được một tháng
# Predicted Aspects:
# Ground Truth Aspects:
#
# Input: mọi người nên mua
# Predicted Aspects:
# Ground Truth Aspects:
#
# Input: mình xài 970 evo đc 3 năm nay upgrade
# Predicted Aspects: 970 evo
# Ground Truth Aspects: 970 evo
#
# Input: hy vọng shop bảo hành 3 năm đúng như trên mô tả
# Predicted Aspects: shop bo hành
# Ground Truth Aspects: bảo hành
#
# Input: ổ cứng tốt
# Predicted Aspects:
# Ground Truth Aspects: ổ cứng
#
# Input: sp chính hãng
# Predicted Aspects: sp
# Ground Truth Aspects: sp
#
# Input: hàng giao đúng đang test thấy ok
# Predicted Aspects: giao test
# Ground Truth Aspects: giao hàng
#
# Input: đóng gói cẩn thận đúng phong cách tiki
# Predicted Aspects: óng gói
# Ground Truth Aspects: đóng gói
#
# Input: ghi hình rất lẹ
# Predicted Aspects: ghi hnh
# Ground Truth Aspects: ghi hình
#
# Input: tiện cho việc học
# Predicted Aspects:
# Ground Truth Aspects:
#
# Input: nói về hàng cao cấp thì tiki là miễn bàn
# Predicted Aspects: hàng cao
# Ground Truth Aspects: hàng cao cấp
#
# Input: hàng giao đúng như hình
# Predicted Aspects: giao hàng
# Ground Truth Aspects: giao hàng
#
# Input: hài lòng !!
# Predicted Aspects:
# Ground Truth Aspects:
#
# Input: được đấy
# Predicted Aspects:
# Ground Truth Aspects:
#
# Input: hàng điện tử giá trị cao mà tiki nhét giấy qua loa đại khái vào
# Predicted Aspects: giá tr cao mà tiki
# Ground Truth Aspects: đóng gói hàng điện tử
#
# Input: 860
# Predicted Aspects:
# Ground Truth Aspects:
#
# Input: ram laptop samsung dùng ok đấy
# Predicted Aspects: ram laptop
# Ground Truth Aspects: ram laptop samsung
#
# Input: ram made in philippines ?? đúng ddr3l
# Predicted Aspects: ram made in philippines
# Ground Truth Aspects: ram ddr3l
#
# Input: đắt nó sắt ra miếng
# Predicted Aspects:
# Ground Truth Aspects:
#
# Input: chất lượng đó
# Predicted Aspects: lng
# Ground Truth Aspects: chất lượng
#
# Input: giá tốt
# Predicted Aspects: giá
# Ground Truth Aspects: giá
#
# Input: ra bưu điện gửi trả lại hàng cũng không mất phí giao
# Predicted Aspects: giao hàng
# Ground Truth Aspects: gửi trả phí giao
#
# Input: hình ảnh đẹp sắc nét
# Predicted Aspects: sc nét
# Ground Truth Aspects: hình ảnh
#
# Input: nguyên seal ok tốt
# Predicted Aspects: nguyên seal
# Ground Truth Aspects: nguyên seal
#
# Input: sản phẩm đẹp
# Predicted Aspects: sn phm
# Ground Truth Aspects: sản phẩm
#
# Input: dùng hơn 200 tờ là đã hết mực
# Predicted Aspects:
# Ground Truth Aspects: mực
#
# Input: xài hơn 2 tháng rồi nhưng chưa thấy vấn đề gì
# Predicted Aspects:
# Ground Truth Aspects:
#
# Input: lần đầu mua 1 thanh
# Predicted Aspects:
# Ground Truth Aspects:
#
# Input: mã vna
# Predicted Aspects:
# Ground Truth Aspects: mã vna
#
# Input: về shipping thời gian giao hàng không nhanh lắm
# Predicted Aspects: shipping giao hàng
# Ground Truth Aspects: shipping giao hàng
#
# Input: giờ chúng tôi chia tay rồi
# Predicted Aspects: gi chng
# Ground Truth Aspects:
#
# Input: đẹp
# Predicted Aspects:
# Ground Truth Aspects:
#
# Input: máy mau nóng cực kỳ
# Predicted Aspects: máy
# Ground Truth Aspects: máy nóng
#
# Input: dung lượng đúng
# Predicted Aspects: dung lng
# Ground Truth Aspects: dung lượng
#
# Input: sản phẩm tiki giao hàng nhanh
# Predicted Aspects: giti hàng
# Ground Truth Aspects: giao hàng sản phẩm
#
# Input: mình ms lấy màn này 2708
# Predicted Aspects: màn
# Ground Truth Aspects: màn
#
# Input: ko có nhu cầu cao
# Predicted Aspects:
# Ground Truth Aspects:
#
# Input: chỉ tiếc là ko tương thích với mac chip m1
# Predicted Aspects: mac chip m1
# Ground Truth Aspects: tương thích mac chip m1
#
# Input: đã mua 5 cây ram samsung 16gb bus 2666 shop lagihitech2
# Predicted Aspects: shop lagihitech2
# Ground Truth Aspects: ram samsung 16gb bus 2666
#
# Input: ram dùng ngon
# Predicted Aspects: ram
# Ground Truth Aspects: ram
#
# Input: giao hàng nhanh xài dc vài ngày thấy sp ok phù hợp với giá tiền
# Predicted Aspects: giao hàng
# Ground Truth Aspects: giao hàng sp giá tiền
#
# Input: giá tốt so với nơi khác
# Predicted Aspects: giá
# Ground Truth Aspects: giá
#
# Input: nhờ hỗ trợ bổ sung thông tin hoá đơn
# Predicted Aspects: h tr
# Ground Truth Aspects: hỗ trợ hoá đơn
#
# Input: giao hàng trong 3 tiếng
# Predicted Aspects: giao hàng
# Ground Truth Aspects: giao hàng
#
# Input: ok
# Predicted Aspects:
# Ground Truth Aspects:
#
# Input: dùng ổn
# Predicted Aspects:
# Ground Truth Aspects:
#
# Input: cực kỳ hài lòng shop
# Predicted Aspects: shop
# Ground Truth Aspects: shop
#
# Input: và shop lagihitech
# Predicted Aspects: shop
# Ground Truth Aspects: shop
#
# Input: giao hàng nhanh
# Predicted Aspects: gio hàng
# Ground Truth Aspects: giao hàng
#
# Input: a shipper giao nhanh thân thiện
# Predicted Aspects: shipper giao
# Ground Truth Aspects: shipper giao
#
# Input: nguyên kiện
# Predicted Aspects: nguyên
# Ground Truth Aspects: nguyên kiện
#
# Input: màn ok
# Predicted Aspects: màn
# Ground Truth Aspects: màn
#
# Input: giao hàng nhanh
# Predicted Aspects: gio hàng
# Ground Truth Aspects: giao hàng
#
# Input: 4 gbps
# Predicted Aspects: 4 gbps
# Ground Truth Aspects: 4 gbps
#
# Input: khá ok
# Predicted Aspects:
# Ground Truth Aspects:
#
# Input: ok
# Predicted Aspects:
# Ground Truth Aspects:
#
# Input: vote 5 sao
# Predicted Aspects:
# Ground Truth Aspects:
#
# Input: bảo hành kích hoạt ngay khi mở máy
# Predicted Aspects: hot ngay
# Ground Truth Aspects: bảo hành
#
# Input: màu sắc ok
# Predicted Aspects: màu
# Ground Truth Aspects: màu sắc
#
# Input: giao hàng hơi chậm nhưng là hàng chính hãng nên yên tâm và mua lại nhiều lần!
# Predicted Aspects: giao hàng
# Ground Truth Aspects: giao hàng hàng chính hãng
#
# Input: tuyệt vời
# Predicted Aspects:
# Ground Truth Aspects:
#
# Input: hình ảnh không được rõ nét lắm
# Predicted Aspects: hnh nh
# Ground Truth Aspects: hình ảnh
#
# Input: màn hình chính hãng
# Predicted Aspects: màn hnh chnh
# Ground Truth Aspects: màn hình chính hãng
#
# Input: màn hình to nên cầm không gọn tay bù lại xem clip rất thích
# Predicted Aspects: màn hnh
# Ground Truth Aspects: màn hình
#
# Input: ngon bổ rẻ ship siêu nhanh
# Predicted Aspects: ship
# Ground Truth Aspects: ship
#
# Input: giao nhanh sản phẩm chính hãng
# Predicted Aspects: giao hàng
# Ground Truth Aspects: giao sản phẩm chính hãng
#
# Input: chạy rất mượt
# Predicted Aspects: chy rt
# Ground Truth Aspects:
#
# Input: giao hàng đúng trong khoảng thời gian giới hạn hàng được giao vẫn nằm trong hộp
# Predicted Aspects: giao hàng gii hn hàng
# Ground Truth Aspects: giao hàng hàng
#
# Input: đã nhận dc đt sau 1 tuần sử dụng mình thấy oke nhưng mà sao đt của mình ko thể sạc lên 100 mặc dù đã tắt chức năng sạc 80 hay sạc theo thói quen chỉ để chế độ sac bình thường
# Predicted Aspects: mà sao
# Ground Truth Aspects: đt sạc
#
# Input: good
# Predicted Aspects:
# Ground Truth Aspects:
#
# Input: so sánh giá gữa lazada với tiki cao hơn 1 chút vẫn quyết định mua tiki
# Predicted Aspects: sánh giá
# Ground Truth Aspects: giá
#
# Input: cảm ơn shop
# Predicted Aspects: shop
# Ground Truth Aspects: shop
#
# Input: máy nhận ram luôn
# Predicted Aspects: ram
# Ground Truth Aspects: máy ram
#
# Input: wifi và bluetooth bắt rất nhạy và ổn định
# Predicted Aspects: wifi bluetooth
# Ground Truth Aspects: wifi bluetooth
#
# Input: mình sử dụng các app
# Predicted Aspects: app
# Ground Truth Aspects: app
#
# Input: hàng samsung chính hãng
# Predicted Aspects: chnh hng
# Ground Truth Aspects: hàng samsung chính hãng
#
# Input: check cpu z thì hàng từ cuối năm 2014
# Predicted Aspects: hàng
# Ground Truth Aspects: hàng
#
# Input: máy khó cài với máy tính dòng mac
# Predicted Aspects: máy
# Ground Truth Aspects: máy cài đặt
#
# Input: giao sớm hơn 1 ngày
# Predicted Aspects: giao sm
# Ground Truth Aspects: giao
#
# Input: mong nhận được support từ nhà phân phối
# Predicted Aspects: support nhà phân
# Ground Truth Aspects: support nhà phân phối
#
# Input: nhưng đã liên hệ được hp support để hỗ trợ
# Predicted Aspects: hp support  h
# Ground Truth Aspects: hp support hỗ trợ
#
# Input: sắc nét
# Predicted Aspects:
# Ground Truth Aspects:
#
# Input: sản phẩm tốt
# Predicted Aspects: sn phm
# Ground Truth Aspects: sản phẩm
#
# Input: đã sử dụng về
# Predicted Aspects:
# Ground Truth Aspects:
#
# Input: tốc độ cao good đúng như nhà sản xuất công khai
# Predicted Aspects: tc  cao good
# Ground Truth Aspects: tốc độ
#
# Input: hàng còn nguyên seal
# Predicted Aspects: nguyên seal
# Ground Truth Aspects: nguyên seal
#
# Input: chất lượng màn hình rất tốt
# Predicted Aspects: màn hnh
# Ground Truth Aspects: màn hình
#
# Input: luôn tin tưởng tiki
# Predicted Aspects:
# Ground Truth Aspects:
#
# Input: giao hàng nhanh
# Predicted Aspects: gio hàng
# Ground Truth Aspects: giao hàng
#
# Input: uy tín
# Predicted Aspects:
# Ground Truth Aspects: uy tín
#
# Input: sam pham bo mạch chủ asus h81mk hàng chính hãng
# Predicted Aspects: sam pham bo mch asus h81mk hàng
# Ground Truth Aspects: bo mạch chủ asus h81mk hàng chính hãng
#
# Input: hàng nguyên đai nguyên kiện
# Predicted Aspects: nguyên ai
# Ground Truth Aspects: nguyên đai nguyên kiện
#
# Input: cài pass cho wifi dễ
# Predicted Aspects: wifi
# Ground Truth Aspects: wifi cài pass
#
# Input: đẹp như ý
# Predicted Aspects:
# Ground Truth Aspects:
#
# Input: good sevice
# Predicted Aspects:
# Ground Truth Aspects: service
#
# Input: sao lại là made in philippines vậy shop
# Predicted Aspects: made in philippines
# Ground Truth Aspects: made in philippines
#
# Input: nhận hàng xong set các thứ thấy chạy ok
# Predicted Aspects: chy ok
# Ground Truth Aspects:
#
# Input: ship siêu nhanh
# Predicted Aspects: ship
# Ground Truth Aspects: ship
#
# Input: chất lượng tương xứng với giá
# Predicted Aspects: cht lng
# Ground Truth Aspects: chất lượng giá
#
# Input: hóa đơn gửi kèm qua email luôn
# Predicted Aspects: gi email
# Ground Truth Aspects: hóa đơn
#
# Input: chất lượng ổn do đã dùng 24inch
# Predicted Aspects: 24inch
# Ground Truth Aspects: chất lượng 24inch
#
# Input: điện thoại chính hãng
# Predicted Aspects: in thoi
# Ground Truth Aspects: điện thoại chính hãng
#
# Input: rồi đổ lỗi cho người mua hay sao? đây là lần 2 mua ram trên tiki
# Predicted Aspects: ram
# Ground Truth Aspects: ram
#
# Input: giao hàng hơi lâu mặc dù tiki trading
# Predicted Aspects: giao hàng
# Ground Truth Aspects: giao hàng tiki trading
#
# Input: xài đc 3ng rồi thấy mọi thứ đều ok hết
# Predicted Aspects:
# Ground Truth Aspects:
#
# Input: mất 2 hôm thăm dò thị trường
# Predicted Aspects:
# Ground Truth Aspects:
#
# Input: cái tuần giao mới gửi mail
# Predicted Aspects: giao
# Ground Truth Aspects: giao
#
# Input: rất oke
# Predicted Aspects:
# Ground Truth Aspects:
#
# Input: ok
# Predicted Aspects:
# Ground Truth Aspects:
#
# Input: tóm lại là những ai cần máy gấp
# Predicted Aspects: máy
# Ground Truth Aspects: máy
#
# Input: máy tốt
# Predicted Aspects: máy
# Ground Truth Aspects: máy
#
# Input: máy được đóng gói cẩn thận
# Predicted Aspects: óng gói
# Ground Truth Aspects: đóng gói máy
#
# Input: rất đẹp
# Predicted Aspects:
# Ground Truth Aspects:
#
# Input: sẽ quay lai ung ho tịi
# Predicted Aspects:
# Ground Truth Aspects:
#
# Input: mới nhận máy
# Predicted Aspects:
# Ground Truth Aspects: máy
#
# Input: sử dụng khá tốt
# Predicted Aspects: s dng
# Ground Truth Aspects:
#
# Input: chỉ có 2 miếng giấy lót trên dưới rất ẩu
# Predicted Aspects: giy
# Ground Truth Aspects: đóng gói
#
# Input: mình mới mua 2202
# Predicted Aspects:
# Ground Truth Aspects:
#
# Input: sẽ tiếp tục tin tưởng tiki
# Predicted Aspects:
# Ground Truth Aspects:
#
# Input: china cắm vào máy ko nhận
# Predicted Aspects: máy
# Ground Truth Aspects: máy
#
# Input: chất lượng tương xứng giá tiền không có gì để chê
# Predicted Aspects: cht lng
# Ground Truth Aspects: chất lượng giá tiền
#
# Input: cám ơn shop đã mang sản phẩm lên tiki
# Predicted Aspects: shop  mang sn phm
# Ground Truth Aspects: shop sản phẩm
#
# Input: hàng chính hãng
# Predicted Aspects: chnh hng
# Ground Truth Aspects: hàng chính hãng
#
# Input: máy khá nhẹ
# Predicted Aspects: máy
# Ground Truth Aspects: máy
#
# Input: hàng chuẩn
# Predicted Aspects: hàng
# Ground Truth Aspects: hàng
#
# Input: ship siêu nhanh
# Predicted Aspects: ship
# Ground Truth Aspects: ship
#
# Input: không liên hệ về thông tin bảo hành
# Predicted Aspects: bo hành
# Ground Truth Aspects: bảo hành
#
# Input: không biết có bảo hành gì không ? nếu như mình mua và đánh giá 5 sao tại thời điểm mua và giờ hư thì mình đã không thể kể cho mọi người
# Predicted Aspects: bo hành
# Ground Truth Aspects: bảo hành
#
# Input: dòng ipad mini 5 này chất liệu nhìn đẹp và nhẹ hơn mấy dòng trước
# Predicted Aspects: ipad mini 5
# Ground Truth Aspects: ipad mini 5 chất liệu
#
# Input: ram chất lượng
# Predicted Aspects: ram
# Ground Truth Aspects: ram
#
# Input: kích hoạt bảo hành đúng
# Predicted Aspects: lng
# Ground Truth Aspects: bảo hành
#
# Input: mua tặng bồ
# Predicted Aspects:
# Ground Truth Aspects:
#
# Input: rất hài lòng
# Predicted Aspects:
# Ground Truth Aspects:
#
# Input: ok
# Predicted Aspects:
# Ground Truth Aspects:
#
# Input: giao hàng nhanh gọn
# Predicted Aspects: giao hàng
# Ground Truth Aspects: giao hàng
#
# Input: nhân viên giao hàng chứ đáo
# Predicted Aspects: giao hàng
# Ground Truth Aspects: nhân viên giao hàng
#
# Input: máy chính hãng
# Predicted Aspects: máy
# Ground Truth Aspects: máy chính hãng
#
# Input: hang dam bao
# Predicted Aspects:
# Ground Truth Aspects: hàng
#
# Input: dễ lắp đặt
# Predicted Aspects:
# Ground Truth Aspects: lắp đặt
#
# Input: máy xài ổn
# Predicted Aspects: máy
# Ground Truth Aspects: máy
#
# Input: sp chất lượng
# Predicted Aspects: cht lng
# Ground Truth Aspects: sp chất lượng
#
# Input: bạn mình dùng oki nha
# Predicted Aspects:
# Ground Truth Aspects:
#
# Input: toi gio hang mua ca 2 tuan van chua duoc kich hoat bao hanh
# Predicted Aspects: toi gio hang mua ca 2 tuan van chua duoc
# Ground Truth Aspects: bảo hành
#
# Input: máy thì siêu đẹp
# Predicted Aspects: máy
# Ground Truth Aspects: máy
#
# Input: sẽ ko giữ đc kh đâu
# Predicted Aspects:
# Ground Truth Aspects:
#
# Input: hàng tốt đúng như mô tả
# Predicted Aspects: hàng
# Ground Truth Aspects: hàng
#
# Input: giao hàng nhanh
# Predicted Aspects: gio hàng
# Ground Truth Aspects: giao hàng
#
# Input: có ảnh đơn hàng mang tính chất nhận xu hehe
# Predicted Aspects: nh n hàng
# Ground Truth Aspects:
#
# Input: chuyển từ windows nên hơi bỡ ngỡ chút
# Predicted Aspects: cht lng
# Ground Truth Aspects:
#
# Input: nhìn có độ sâu
# Predicted Aspects:
# Ground Truth Aspects:
#
# Input: chất lượng tốt
# Predicted Aspects: cht lng
# Ground Truth Aspects: chất lượng
#
# Input: ae xài màn ở phòng sáng có lẽ sẽ k lo màn k đủ sáng
# Predicted Aspects: màn
# Ground Truth Aspects: màn độ sáng
#
# Input: rất ok
# Predicted Aspects:
# Ground Truth Aspects:
#
# Input: máy đẹp
# Predicted Aspects: máy
# Ground Truth Aspects: máy
#
# Input: tiki giao hàng nhanh
# Predicted Aspects: gao hàng
# Ground Truth Aspects: giao hàng
#
# Input: đóng gói tốt
# Predicted Aspects: óng gói
# Ground Truth Aspects: đóng gói
#
# Input: tiếc là 256gb hết màu hợp mình
# Predicted Aspects: 256gb màu hp
# Ground Truth Aspects: 256gb màu
#
# Input: hàng giao nhanh
# Predicted Aspects: giao
# Ground Truth Aspects: giao
#
# Input: hàng tốt
# Predicted Aspects: hàng
# Ground Truth Aspects: hàng
#
# Input: hàng ko cho đổi trả khi đổi ý
# Predicted Aspects: hàng
# Ground Truth Aspects: đổi trả
#
# Input: chỉ có khâu thay mực khó khăn
# Predicted Aspects: thay mc
# Ground Truth Aspects: thay mực
#
# Input: nên mua ae nhez
# Predicted Aspects:
# Ground Truth Aspects:
#
# Input: giao nhanh
# Predicted Aspects: giao
# Ground Truth Aspects: giao
#
# Input: giá khuyến mãi trên tiki quá hợp lý để mua
# Predicted Aspects: giá hp
# Ground Truth Aspects: giá khuyến mãi
#
# Input: đien máy chợ lớn nữa
# Predicted Aspects: ch ln
# Ground Truth Aspects:
#
# Input: tiki gói hàng rất kỹ luôn
# Predicted Aspects: gói hàng
# Ground Truth Aspects: gói hàng
#
# Input: thật sự thất vọng
# Predicted Aspects:
# Ground Truth Aspects:
#
# Input: màn hình độ sáng không đều
# Predicted Aspects: màn hnh
# Ground Truth Aspects: màn hình độ sáng
#
# Input: tôi thấy hài lòng
# Predicted Aspects:
# Ground Truth Aspects:
#
# Input: màn hình đẹp
# Predicted Aspects: man hnh
# Ground Truth Aspects: màn hình
#
# Input: ok
# Predicted Aspects:
# Ground Truth Aspects:
#
# Input: đóng gói cẩn thận
# Predicted Aspects: óng gói
# Ground Truth Aspects: đóng gói
#
# Input: hoàn toàn hài lòng và yên tâm khi mua sản phẩm điện tử từ tiki
# Predicted Aspects: sn phm
# Ground Truth Aspects: sản phẩm điện tử
#
# Input: hài lòng
# Predicted Aspects: hài
# Ground Truth Aspects:
#
# Input: sang xịn mịn ạ
# Predicted Aspects:
# Ground Truth Aspects:
#
# Input: gắn vào nhận ngay
# Predicted Aspects: gn vào
# Ground Truth Aspects:
#
# Input: chính hãng
# Predicted Aspects: chnh hng
# Ground Truth Aspects: chính hãng
#
# Input: giao nhanh
# Predicted Aspects: giao
# Ground Truth Aspects: giao
#
# Input: i am happy with this purchase
# Predicted Aspects:
# Ground Truth Aspects:
#
# Input: sản phẩm chính hãng
# Predicted Aspects: chnh hng
# Ground Truth Aspects: sản phẩm chính hãng
#
# Input: khiếu nại tiki cho kỹ thuật hướng dẫn nhưng ko có ai gọi lại hỗ trợ
# Predicted Aspects: thut hng
# Ground Truth Aspects: khiếu nại hỗ trợ kỹ thuật
#
# Input: hàng chính hãng
# Predicted Aspects: chnh hng
# Ground Truth Aspects: hàng chính hãng
#
# Input: rất hài lòng
# Predicted Aspects:
# Ground Truth Aspects:
#
# Input: nhưng không tài nào tải được driver trên trang chủ của hãng
# Predicted Aspects: driver
# Ground Truth Aspects: driver
#
# Input: dùng ok nhé cả nhà
# Predicted Aspects:
# Ground Truth Aspects:
#
# Input: 35v chạy ổn định cho dell 5447 nha
# Predicted Aspects: 35v dell 5447
# Ground Truth Aspects: 35v dell 5447
#
# Input: ram ngon
# Predicted Aspects: ram
# Ground Truth Aspects: ram
#
# Input: mình toàn là mua hàng điện tử trên tiki thôi
# Predicted Aspects: mnh toàn
# Ground Truth Aspects: hàng điện tử
#
# Input: màn vẫn làm việc tốt
# Predicted Aspects: màn
# Ground Truth Aspects: màn
#
# Input: máy tốt
# Predicted Aspects: máy
# Ground Truth Aspects: máy
#
# Input: thông số đúng như trong cpuz cám ơn shop
# Predicted Aspects: shop
# Ground Truth Aspects: thông số shop
#
# Input: tikinow giao hàng cực nhanh và cẩn thận
# Predicted Aspects: giao hàng
# Ground Truth Aspects: tikinow giao hàng
#
# Input: mua về cho cty dùng rất oke luôn
# Predicted Aspects:
# Ground Truth Aspects:
#
# Input: dùng oke
# Predicted Aspects:
# Ground Truth Aspects:
#
# Input: còn 13 vạch nếu dùng 5ghz
# Predicted Aspects: 5ghz
# Ground Truth Aspects: 5ghz
#
# Input: tiki đóng gói rất cẩn thận
# Predicted Aspects: óng gói
# Ground Truth Aspects: đóng gói
#
# Input: haizz
# Predicted Aspects:
# Ground Truth Aspects:
#
# Input: giao hàng nhanh
# Predicted Aspects: gio hàng
# Ground Truth Aspects: giao hàng
#
# Input: được giải đáp thông tin bảo hành cụ thể
# Predicted Aspects: c gii
# Ground Truth Aspects: bảo hành
#
# Input: hàng hẹn giao t5 mà t3 mình đã nhận được rồi
# Predicted Aspects: giao hàng
# Ground Truth Aspects: giao hàng
#
# Input: rất ok
# Predicted Aspects:
# Ground Truth Aspects:
#
# Input: đó là quan điểm và ý kiến riêng của mình
# Predicted Aspects:
# Ground Truth Aspects:
#
# Input: nghệ an
# Predicted Aspects:
# Ground Truth Aspects:
#
# Input: chắc chắn
# Predicted Aspects:
# Ground Truth Aspects:
#
# Input: cái của mình bị hơi nhiều bên góc dưới phải màn hình
# Predicted Aspects: màn hnh
# Ground Truth Aspects: màn hình
#
# Input: chắc chắn
# Predicted Aspects:
# Ground Truth Aspects:
#
# Input: hàng samsung sử dụng ổn
# Predicted Aspects: hàng samsung
# Ground Truth Aspects: hàng samsung
#
# Input: mình thiệt là shock
# Predicted Aspects:
# Ground Truth Aspects:
#
# Input: lắp vô máy chạy rất êm luôn ne chung là tuyệt
# Predicted Aspects: máy chy
# Ground Truth Aspects: máy
#
# Input: hàng đúng mô ta
# Predicted Aspects: hàng
# Ground Truth Aspects: hàng
#
# Input: tại sao một kit mực báo lỗi khi cắm vào máy in
# Predicted Aspects: kit mc
# Ground Truth Aspects: kit mực máy in
#
# Input: cpu và ram tốt nên xử lý nhanh
# Predicted Aspects: ram
# Ground Truth Aspects: cpu ram
#
# Input: hộp giao đến k seal máy bóc ra dùng dc 1 ngày đã đơ lag kinh khủng
# Predicted Aspects: seal máy
# Ground Truth Aspects: giao seal máy lag
#
# Input: mua trả góp 0 lại thêm giảm 2tr nữa
# Predicted Aspects: góp 0
# Ground Truth Aspects: trả góp giảm giá
#
# Input: wonderful
# Predicted Aspects:
# Ground Truth Aspects:
#
# Precision: 0.3971
# Recall: 0.3986
# F1 Score: 0.3869
# c:\Users\kietd\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
